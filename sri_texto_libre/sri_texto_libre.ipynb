# %% [markdown]
#  ## 1. Lectura de datos
#
#  Se comenzará con la lectura del corpus. Para lo cual se utilizarán distintas técnicas de normalización de términos, entre las que se incluye la identificación de palabras compuestas.

# %%
# !pip install nltk
import nltk

from nltk import download

download('punkt_tab')                           # Tokenización
nltk.download('averaged_perceptron_tagger')     # POS tagging
nltk.download('averaged_perceptron_tagger_eng') # POS tagging
nltk.download('wordnet')                        # WordNet lemmatizer
nltk.download('omw-1.4')                        # WordNet multilingüe
# Out:
# Requirement already satisfied: nltk in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
from nltk.corpus import stopwords
from nltk.data import path
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from nltk.corpus import wordnet as wn
import numpy as np

path.append(".")

# %%
# !pip install contractions
import contractions
# Out:
# Requirement already satisfied: contractions in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from textsearch>=0.0.21->contractions) (2.1.0)

# %%
import csv
import pandas as pd
from bs4 import BeautifulSoup
from pprint import pprint
import re
from bs4 import MarkupResemblesLocatorWarning
import warnings

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
import spacy

# %%
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
# !pip install whoosh
from whoosh.index import create_in
from whoosh.index import open_dir
from whoosh.fields import Schema, TEXT, ID
from whoosh.qparser import QueryParser
from whoosh.query import Term, Or
import os
import shutil
# Out:
# Requirement already satisfied: whoosh in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (2.7.4)

# %%
warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

# %%
palabras_vacias_ingles = stopwords.words('english')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def elimina_html(contenido):
    return BeautifulSoup(contenido).get_text()

def elimina_no_alfanumerico(contenido):
    return [re.sub(r'[^\w]', '', palabra)
            for palabra in contenido
            if re.search(r'\w', palabra)]

def expandir_constracciones(contenido):
    return contractions.fix(contenido)

def pasar_a_minuscula(contenido):
    return contenido.lower()

def limpiar_texto(texto):
    texto = re.sub(r'[^a-zA-Z\s]', ' ', texto)  # Reemplaza todo lo que no es letra o espacio con espacio
    texto = re.sub(r'\s+', ' ', texto).strip()
    return texto

def elimina_palabras_vacias(contenido):
    return [palabra for palabra in contenido if palabra not in palabras_vacias_ingles]

def lematizador(contenido):
    lemmatizer = WordNetLemmatizer()
    pos_tags = pos_tag(contenido)

    resultado = []
    for palabra, tag in pos_tags:
        if tag.startswith('VB'):  # Verbos
            resultado.append(lemmatizer.lemmatize(palabra, pos='v'))  # infinitivo
        else:  # Sustantivos y el resto tal como están
            resultado.append(palabra)

    return resultado

def extraer_noun_chunks(tokens):
    resultados = []
    doc = nlp(" ".join(tokens))

    noun_chunks = [chunk.text.lower().strip() for chunk in doc.noun_chunks if len(chunk.text.split()) <= 3]
    noun_chunks_set = set(noun_chunks)

    i = 0
    while i < len(tokens):
        composed2 = " ".join(tokens[i:i+2]).lower()
 
        if composed2 in noun_chunks_set:
            i += 2 
        else:
            resultados.append(tokens[i].lower())
            i += 1

    return resultados + noun_chunks

# %%
def proceso_contenido(texto):
    texto = elimina_html(texto)
    texto = expandir_constracciones(texto)
    texto = pasar_a_minuscula(texto)
    texto = limpiar_texto(texto)                # Limpiar antes de tokenizar
    tokens = word_tokenize(texto)               
    tokens = elimina_no_alfanumerico(tokens)    # Limpiar tokens individuales
    tokens = elimina_palabras_vacias(tokens)
    tokens = lematizador(tokens)
    return tokens

# %% [markdown]
#  ## 2. Sistema de recuperación de la información que admite consultas especificadas en texto libre
#
#  Se procederá con el diseño y la evaluación de un sistema de recuperación de información que admite consultas en texto libre. Este se pondrá a prueba, por un lado, utilizando los documentos del corpus junto con sinónimos de las palabras contenidas en ellos, y por otro lado, sin recurrir a dichos sinónimos.

# %%
def lectura_normalizada_corpus():
    df = pd.read_csv("news_corpus.csv", encoding="latin-1", sep=";", quotechar='"')
    resultados = []

    for index, fila in df.iterrows():
        autor = [fila.iloc[0]]
        titulo = fila.iloc[1]
        cuerpo = fila.iloc[2]   

        titulo_proc = proceso_contenido(titulo)
        cuerpo_proc = proceso_contenido(cuerpo)

        # Unir las tres listas en una sola lista combinada
        fila_combinada =  autor + titulo_proc + cuerpo_proc

        contenido_final = extraer_noun_chunks(fila_combinada)
        resultados.append(contenido_final)
    return resultados

def expand_term(term):
    related = set()
    for syn in wn.synsets(term):
        for lemma in syn.lemmas():
            word = lemma.name().replace('_', ' ').lower()
            if word != term:
                related.add(word)
    return related

def expand_corpus_with_synonyms(documento):
    doc_counter = Counter(documento)
    expanded_doc = []
    for word, count in doc_counter.items():
        # Añadimos la palabra original tantas veces como aparece
        expanded_doc.extend([word] * count)
        # Obtenemos sinónimos y también los añadimos con la misma frecuencia
        synonyms = expand_term(word)
        for syn in synonyms:
            expanded_doc.extend([syn] * count)
    return expanded_doc

def lectura_normalizada_corpus_sinonimos():
    df = pd.read_csv("news_corpus.csv", encoding="latin-1", sep=";", quotechar='"')
    resultados = []

    for index, fila in df.iterrows():
        autor = [fila.iloc[0]]
        titulo = fila.iloc[1]
        cuerpo = fila.iloc[2]   

        titulo_proc = proceso_contenido(titulo)
        cuerpo_proc = proceso_contenido(cuerpo)

        # Unir las tres listas en una sola lista combinada
        fila_combinada =  autor + titulo_proc + cuerpo_proc

        contenido_con_palabras_compuestas = extraer_noun_chunks(fila_combinada)
        contenido_final = expand_corpus_with_synonyms(contenido_con_palabras_compuestas)

        resultados.append(contenido_final)
    return resultados

def crear_indice_whoosh(corpus_normalizado):
    if os.path.exists("indice_whoosh"):
        shutil.rmtree("indice_whoosh")  # Elimina índice anterior si existe
    os.mkdir("indice_whoosh")

    schema = Schema(id=ID(stored=True, unique=True), contenido=TEXT(stored=True))
    ix = create_in("indice_whoosh", schema)
    writer = ix.writer()

    for i, doc in enumerate(corpus_normalizado):
        contenido = " ".join(doc)
        writer.add_document(id=str(i), contenido=contenido)
    
    writer.commit()


def buscar_con_whoosh(tokens_query, corpus_normalizado):
    ix = open_dir("indice_whoosh")  # Abrir índice Whoosh previamente creado

    with ix.searcher() as searcher:
        # Crear la consulta OR con todos los términos
        terms = [Term("contenido", token) for token in tokens_query]
        query = Or(terms)

        resultados = searcher.search(query, limit=None)

        # Crear diccionario: clave = doc_id, valor = documento procesado
        docs_encontrados = []
        indices_docs = []
        for hit in resultados:
            doc_id = int(hit['id'])
            docs_encontrados.append(corpus_normalizado[doc_id])
            indices_docs.append(doc_id)

        return docs_encontrados, indices_docs

# %%
def lectura_documento(documento):
    documento_procesado = proceso_contenido(documento) 
    contenido_final = extraer_noun_chunks(documento_procesado)
    return contenido_final

def lectura_documento_sinonimos(documento):
    documento_procesado = proceso_contenido(documento) 
    contenido_final = extraer_noun_chunks(documento_procesado)
    resultado = expand_corpus_with_synonyms(contenido_final)
    return resultado

# %%
# Mostrar los primeros 3 documentos procesados
def prueba_primeros_3_documentos_procesados(corpus):
    for i, documento in enumerate(corpus[:3]):
        print(f"Documento {i+1}:")
        print(" - Palabras:", documento)
        print()

# %%
def tfidf_del_documento(documento_normalizado, vectorizer):
    # Convertir el documento (lista de tokens) a string
    texto = " ".join(documento_normalizado)
    # Transformar usando el vectorizador ya entrenado
    X_doc = vectorizer.transform([texto])  # devuelve matriz sparse 1xN
    return X_doc

# %%
def prueba_tfdifs_primeros_3_documentos(lista_diccionarios_tfidfs):
    for idx, d in enumerate(lista_diccionarios_tfidfs[:3]):
        top_terms = sorted(d.items(), key=lambda x: x[1], reverse=True)
        print(f"\n Documento {idx+1}:")
        print("      Palabras añadidas por TF-IDF:")
        for term, score in top_terms:
            print(f"      - {term}: {score:.4f}")

# %%
def tfidf_por_corpus(corpus_normalizado):
    # Convertimos el corpus a lista de strings
    texts = [" ".join(doc) for doc in corpus_normalizado]

    # Vectorizador TF-IDF (1 y 2-gramas)
    vectorizer = TfidfVectorizer(ngram_range=(1, 2))
    X = vectorizer.fit_transform(texts)  # Matriz TF-IDF sparse
    terms = vectorizer.get_feature_names_out()

    # Retornamos la matriz y vocabulario (términos)
    return X, terms, vectorizer

# %%
def similitud_coseno(tfidf_corpus, tfidf_doc, indices, umbral=0.0):
    # Calcular similitud coseno entre documento y corpus
    similitudes = cosine_similarity(tfidf_doc, tfidf_corpus).flatten()

    # Filtrar documentos que superan el umbral
    indices_filtrados = [i for i, sim in enumerate(similitudes) if sim > umbral]

    # Ordenar índices por similitud descendente
    indices_ordenados = sorted(indices_filtrados, key=lambda i: similitudes[i], reverse=True)

    # Devolver lista de (indice, similitud)
    return [(indices[i], similitudes[i]) for i in indices_ordenados]

def documentos_similares(lista_similitudes):
    lista_similitudes[0]
    for idx, score in lista_similitudes:
        print(f"Documento {idx} tiene similitud: {score:.4f}")

# %%
# Prueba de lectura 
resultados = lectura_normalizada_corpus()
prueba_primeros_3_documentos_procesados(resultados)
# Out:
# Documento 1:
#  - Palabras: ['diu', 'revoke', 'mandatory', 'rakshabandhan', 'offices', 'order', 'daman', 'wednesday', 'withdraw', 'circular', 'ask', 'tie', 'rakhis', 'male', 'colleagues', 'order', 'trigger', 'backlash', 'employees', 'rip', 'apart', 'social', 'media', 'union', 'territory', 'administration', 'force', 'retreat', 'within', 'circular', 'make', 'celebrate', 'decide', 'celebrate', 'festival', 'rakshabandhan', 'august', 'connection', 'offices', 'departments', 'shall', 'remain', 'open', 'celebrate', 'festival', 'collectively', 'suitable', 'time', 'wherein', 'shall', 'tie', 'rakhis', 'colleagues', 'order', 'issue', 'august', 'gurpreet', 'singh', 'deputy', 'secretary', 'personnel', 'say', 'ensure', 'one', 'skipped', 'office', 'attendance', 'report', 'send', 'government', 'next', 'even', 'two', 'notifications', 'one', 'mandate', 'celebration', 'rakshabandhan', 'leave', 'withdraw', 'mandate', 'daman', 'day', 'apart', 'circular', 'withdrawn', 'one', 'line', 'order', 'issue', 'late', 'evening', 'ut', 'department', 'personnel', 'administrative', 'reforms', 'circular', 'ridiculous', 'sensitivities', 'involve', 'government', 'dictate', 'maintain', 'professionalism', 'workplace', 'official', 'tell', 'earlier', 'day', 'refuse', 'identified', 'daman', 'former', 'gujarat', 'home', 'minister', 'praful', 'kodabhai', 'patel', 'direction', 'sources', 'say', 'rakshabandhan', 'celebration', 'bond', 'brothers', 'sisters', 'one', 'several', 'hindu', 'festivities', 'rituals', 'longer', 'confine', 'private', 'family', 'affairs', 'become', 'tools', 'push', 'politic', 'al', 'ideologies', 'year', 'bjp', 'storm', 'power', 'centre', 'rashtriya', 'rss', 'chief', 'mohan', 'bhagwat', 'say', 'festival', 'national', 'significance', 'celebrate', 'widely', 'protect', 'hindu', 'culture', 'live', 'values', 'enshrine', 'rss', 'ideological', 'parent', 'ruling', 'bjp', 'last', 'year', 'modi', 'government', 'go', 'celebrate', 'festival', 'soldiers', 'year', 'cabinet', 'ministers', 'ask', 'go', 'chhavi tyagi daman', 'diu', 'diu administration', 'women staff', 'hours issue', 'compulsory staff', 'rakshabandhan workplace', 'open celebrate festival', 'lady staff', 'government', 'even two notifications', 'mandate', 'right issue', 'circular ridiculous sensitivities', 'government', 'tie rakhi', 'professionalism workplace official', 'hindustan times', 'notice issue', 'diu administrator', 'rituals', 'private family affairs', 'tools', 'swayamsevak sangh', 'chief mohan bhagwat', 'festival national significance', 'women ministers', 'government', 'border areas', 'constituencies festival']
#
# Documento 2:
#  - Palabras: ['slams', 'user', 'troll', 'divorcing', 'rich', 'man', 'special', 'numbers', 'bollywood', 'actor', 'malaika', 'arora', 'khan', 'manage', 'carve', 'identity', 'actor', 'make', 'debut', 'hindi', 'film', 'industry', 'blockbuster', 'debut', 'opposite', 'shah', 'rukh', 'khan', 'chaiyya', 'chaiyya', 'still', 'remember', 'song', 'however', 'trolls', 'woman', 'first', 'matters', 'right', 'divorce', 'rich', 'man', 'wednesday', 'malaika', 'arora', 'share', 'gorgeous', 'picture', 'instagram', 'follower', 'decide', 'troll', 'use', 'alumni', 'read', 'wear', 'go', 'gym', 'salon', 'little', 'know', 'munni', 'badnam', 'star', 'would', 'reply', 'take', 'look', 'interaction', 'super', 'excite', 'affiliated', 'khanna', 'jewellers', 'khannajewellerskj', 'brand', 'ambassador', 'craft', 'perfection', 'stun', 'statement', 'jewellery', 'must', 'every', 'jewellery', 'lover', 'khannajewellers', 'maksquad', 'hair', 'hairbypriyanka', 'stylist', 'manekaharisinghani', 'manager', 'ektakauroberoi', 'mua', 'subbu', 'photographer', 'prasdnaik', 'post', 'share', 'malaika', 'arora', 'khan', 'malaikaarorakhanofficial', 'aug', 'pdt', 'malaika', 'decide', 'reply', 'entire', 'conversation', 'prove', 'matter', 'woman', 'successful', 'attack', 'moment', 'decides', 'step', 'bounds', 'society', 'decide', 'apart', 'successful', 'woman', 'live', 'life', 'terms', 'malaika', 'literally', 'play', 'roles', 'traditionally', 'prescribe', 'woman', 'marry', 'quite', 'early', 'son', 'raise', 'always', 'around', 'khandan', 'get', 'divorce', 'alimony', 'taunt', 'thrown', 'details', 'alimony', 'know', 'malaika', 'husband', 'arbaaz', 'khan', 'perhaps', 'family', 'couple', 'handle', 'divorce', 'need', 'alimony', 'buy', 'clothes', 'go', 'vacations', 'enjoy', 'life', 'anything', 'successful', 'happen', 'arbaaz', 'malaika', 'personal', 'concern', 'claim', 'malaika', 'marry', 'divorce', 'arbaaz', 'money', 'hold', 'water', 'agree', 'please', 'get', 'course', 'playlist', 'follow', 'daisy mowke malaika', 'tv appearances', 'carve identity actor', 'dil se', 'song', 'woman', 'wednesday malaika arora', 'gorgeous picture instagram', 'follower', 'troll use alumni', 'alimony money', 'short clothes', 'perfect comeback', 'interaction', 'every jewellery lover', 'reply entire conversation', 'step bounds society', 'roles', 'woman', 'quite early son', 'khandan', 'divorce', 'utmost dignity', 'vouch fact', 'alimony', 'clothes', 'short choice', 'vacations', 'life', 'anything', 'ex husband', 'malaika', 'divorce arbaaz money', 'water', 'feminism others', 'popular songs', 'htshowbiz']
#
# Documento 3:
#  - Palabras: ['arshiya chopra', 'virgin', 'correct', 'unmarried', 'igims', 'form', 'indira', 'gandhi', 'institute', 'medical', 'sciences', 'igims', 'patna', 'amend', 'marital', 'declaration', 'form', 'thursday', 'replace', 'word', 'virgin', 'unmarried', 'controversy', 'super', 'specialty', 'medical', 'institute', 'state', 'capital', 'require', 'declare', 'bachelors', 'widowers', 'virgins', 'igims', 'dr', 'manish', 'mandal', 'say', 'institute', 'director', 'dr', 'nr', 'biswas', 'hold', 'meeting', 'thursday', 'morning', 'directing', 'word', 'virgin', 'marital', 'declaration', 'form', 'immediately', 'replace', 'biswas', 'return', 'four', 'day', 'leave', 'absence', 'earlier', 'bihar', 'health', 'minister', 'mangal', 'pandey', 'end', 'redefine', 'mean', 'virginity', 'attempts', 'justify', 'awkward', 'phrase', 'question', 'form', 'follow', 'public', 'furore', 'document', 'tell', 'nothing', 'wrong', 'use', 'word', 'virgin', 'simply', 'meant', 'kanya', 'kunwari', 'mean', 'unmarried', 'girl', 'pandey', 'join', 'cabinet', 'three', 'days', 'ago', 'sources', 'say', 'chief', 'minister', 'office', 'also', 'take', 'ask', 'even', 'ask', 'question', 'introduce', 'first', 'place', 'response', 'management', 'autonomous', 'super', 'specialty', 'health', 'facility', 'clarify', 'wednesday', 'adherence', 'central', 'civil', 'services', 'rules', 'follow', 'india', 'institute', 'medical', 'sciences', 'new', 'delhi', 'previous', 'version', 'marital', 'declaration', 'form', 'purportedly', 'ask', 'virgins', 'ht', 'photo', 'marital', 'declaration', 'form', 'existence', 'since', 'inception', 'institute', 'officials', 'blame', 'faux', 'pas', 'poor', 'translation', 'part', 'individuals', 'draft', 'form', 'nothing', 'seek', 'know', 'employees', 'marital', 'status', 'dues', 'could', 'settle', 'basis', 'declaration', 'event', 'death', 'service', 'say', 'new recruits', 'bachelors', 'virgins', 'medical superintendent', 'dr manish mandal', 'unmarried dr', 'public furore document', 'wednesday minister', 'news channels', 'nothing', 'sources', 'chief minister office', 'cognizance issue', 'copy form', 'question', 'inception institute officials', 'document word', 'virgin mention', 'nothing', 'virginity employee', 'dr mandal']

# %%
import json

def cargar_consultas(nombre_archivo):
    """Carga las consultas desde un archivo JSON y las devuelve."""
    with open(nombre_archivo, "r", encoding="utf-8") as f:
        consultas = json.load(f)
    return consultas

def mostrar_consultas_ejemplo(consultas, n=2):
    """Muestra las primeras `n` consultas para verificación."""
    print(f"Se han cargado {len(consultas)} consultas.")
    for i in range(min(n, len(consultas))):
        print(f"Consulta {i+1}:", consultas[i])

# %%
# 2.4. Cargar las consultas

nombre_archivo="consultas_texto_libre.json"

consultas = cargar_consultas(nombre_archivo)
mostrar_consultas_ejemplo(consultas)
# Out:
# Se han cargado 66 consultas.
# Consulta 1: {'query': 'News about Donald Trump', 'documentos': [32, 33, 35, 37, 40, 43]}
# Consulta 2: {'query': 'Information about films, series and shows', 'documentos': [41, 46, 47, 48]}

# %%
from sklearn.metrics import average_precision_score

def calcular_metricas(resultados_similitud, documentos_relevantes, indices_posibles):
    y_true_positive = []
    y_false_positive = []
    y_scores = []
    idxs = []

    for idx, score in resultados_similitud:
        y_true_positive.append(1 if idx in documentos_relevantes else 0)
        y_false_positive.append(1 if idx not in documentos_relevantes else 0)
        y_scores.append(score)
        idxs.append(idx)

    no_relevantes = [i for i in indices_posibles if i not in idxs]
    y_true_negative = [1 if i not in documentos_relevantes else 0 for i in no_relevantes]
    y_false_negative = [1 if i in documentos_relevantes else 0 for i in no_relevantes]

    if any(y_true_positive):
        ap = average_precision_score(y_true_positive, y_scores)
        precision = sum(y_true_positive) / (sum(y_true_positive) + sum(y_false_positive))
        recall = sum(y_true_positive) / (sum(y_true_positive) + sum(y_false_negative))
        return ap, precision, recall, idxs, y_scores
    else:
        return None, None, None, idxs, y_scores


def mostrar_resultados(texto_query, documentos_relevantes, resultados_similitud, ap, precision, recall):
    print(f"Consulta: {texto_query}")
    print(f"Documentos relevantes esperados: {sorted(documentos_relevantes)}")
    print(f"Documentos recuperados ordenados: {[i for i, _ in resultados_similitud]}")
    print(f"Average Precision: {ap:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print("-" * 60)


def evaluar_consultas_por_similitud(consultas, corpus_normalizado):
    crear_indice_whoosh(corpus_normalizado)
    map_scores = []
    map_precision = []
    map_recall = []
    #indices_posibles = list(range(len(corpus_normalizado)))
    indices_posibles = list(range(51))

    for consulta in consultas:
        texto_query = consulta["query"]
        documentos_relevantes = set(consulta["documentos"])

        lectura = lectura_documento(texto_query)
        docs_relevantes, indices_docs = buscar_con_whoosh(lectura, corpus_normalizado)
        tfidf_corpus, terms, vectorizer = tfidf_por_corpus(docs_relevantes)
        tfidf_documento = tfidf_del_documento(lectura, vectorizer)
        resultados_similitud = similitud_coseno(tfidf_corpus, tfidf_documento, indices_docs)

        # Lógica de métricas
        ap, precision, recall, idxs, y_scores = calcular_metricas(resultados_similitud, documentos_relevantes, indices_posibles)

        if ap is not None:
            map_scores.append(ap)
            map_precision.append(precision)
            map_recall.append(recall)

            mostrar_resultados(texto_query, documentos_relevantes, resultados_similitud, ap, precision, recall)
        else:
            print(f"Consulta: {texto_query}")
            print("No hay documentos relevantes etiquetados para esta consulta. Se omite en MAP.")
            print("-" * 60)

    return map_scores, map_precision, map_recall

# %%
#Calculo de similitudes para cada consulta sin hacer uso de sinónimos

corpus_normalizado = lectura_normalizada_corpus()
corpus_normalizado_reducido = corpus_normalizado[0:51]
map_scores, map_precision, map_recall = evaluar_consultas_por_similitud(consultas, corpus_normalizado_reducido)
# Out:
# Consulta: News about Donald Trump
# Documentos relevantes esperados: [32, 33, 35, 37, 40, 43]
# Documentos recuperados ordenados: [32, 35, 37, 40, 33, 43, 9, 16, 19, 20, 11, 2, 36]
# Average Precision: 1.0000
# Precision: 0.4615
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Information about films, series and shows
# Documentos relevantes esperados: [41, 46, 47, 48]
# Documentos recuperados ordenados: [47, 34, 46, 37, 41, 28, 11, 23, 33, 29]
# Average Precision: 0.7556
# Precision: 0.3000
# Recall: 0.7500
# ------------------------------------------------------------
# Consulta: Cases related to racism and hindu culture in offices
# Documentos relevantes esperados: [42]
# Documentos recuperados ordenados: [0, 42, 50, 19, 20, 7, 45, 25, 36, 4]
# Average Precision: 0.5000
# Precision: 0.1000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Data on economy and finance
# Documentos relevantes esperados: [44, 45]
# Documentos recuperados ordenados: [44, 26, 38, 45, 23]
# Average Precision: 0.7500
# Precision: 0.4000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Topics on feminism and women's rights
# Documentos relevantes esperados: [34, 36, 47]
# Documentos recuperados ordenados: [1, 7, 36, 0, 42, 22, 31, 18, 13, 39, 4, 19]
# Average Precision: 0.3333
# Precision: 0.0833
# Recall: 0.3333
# ------------------------------------------------------------
# Consulta: Security forces and police operations
# Documentos relevantes esperados: [30, 31, 39, 49]
# Documentos recuperados ordenados: [31, 30, 3, 39, 5, 27, 49, 7, 17, 34, 25, 4, 21, 33, 9, 6, 16, 24, 41]
# Average Precision: 0.8304
# Precision: 0.2105
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Political situation in the United States (US)
# Documentos relevantes esperados: [32, 33, 35, 40, 43]
# Documentos recuperados ordenados: [43, 40, 26, 25, 8, 9, 23, 3, 7, 4]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 0.4000
# ------------------------------------------------------------
# Consulta: Politics in India (Delhi)
# Documentos relevantes esperados: [36, 39, 42, 44]
# Documentos recuperados ordenados: [16, 14, 29, 44, 21, 18, 38, 5, 17, 7, 2, 28, 46, 10, 6, 4, 30, 22]
# Average Precision: 0.2500
# Precision: 0.0556
# Recall: 0.2500
# ------------------------------------------------------------
# Consulta: Armed conflicts in which ballistic missiles have been used
# Documentos relevantes esperados: [40]
# Documentos recuperados ordenados: [26, 40, 43, 20, 18, 39, 15, 1, 41, 50, 4, 2, 13, 5, 36, 23, 12, 3, 10]
# Average Precision: 0.5000
# Precision: 0.0526
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Environment, ecology and health
# Documentos relevantes esperados: [38, 39]
# Documentos recuperados ordenados: [39, 2, 45, 34, 18, 37, 25, 10, 13]
# Average Precision: 1.0000
# Precision: 0.1111
# Recall: 0.5000
# ------------------------------------------------------------
# Consulta: Ailments caused by pollutant
# Documentos relevantes esperados: [38]
# Documentos recuperados ordenados: [38, 13, 6, 24, 39]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Imposition of Rakshabandhan religious celebration in offices
# Documentos relevantes esperados: [0]
# Documentos recuperados ordenados: [0, 42, 12]
# Average Precision: 1.0000
# Precision: 0.3333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Controversies over mandatory labor regulations related to religion in the workplace
# Documentos relevantes esperados: [0]
# Documentos recuperados ordenados: [0, 42, 4, 45, 5]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Criticism of famous women after divorce
# Documentos relevantes esperados: [1]
# Documentos recuperados ordenados: [1, 29, 33, 19, 7, 36, 0, 42, 22, 31, 18, 13, 39, 4]
# Average Precision: 1.0000
# Precision: 0.0714
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Misogyny on social media toward successful and independent woman
# Documentos relevantes esperados: [1]
# Documentos recuperados ordenados: [1, 5, 0, 7, 42, 36, 45, 24, 26, 43, 46, 11, 4, 22, 20, 32, 39, 19, 33]
# Average Precision: 1.0000
# Precision: 0.0526
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Controversy over an inappropriate institutional form
# Documentos relevantes esperados: [2]
# Documentos recuperados ordenados: [2, 18, 16, 20, 13, 21]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Woman reports inappropriate questions on a form asking if she was a virgin or unmarried
# Documentos relevantes esperados: [2]
# Documentos recuperados ordenados: [18, 2, 5, 1, 16, 7, 20, 4, 34, 3, 46, 33, 36, 13, 9, 21, 30, 39, 47, 24, 0, 42, 19, 41, 22, 8, 25]
# Average Precision: 0.5000
# Precision: 0.0370
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Death of wanted terrorists in Kashmir
# Documentos relevantes esperados: [3]
# Documentos recuperados ordenados: [5, 43, 3, 31, 30, 7, 19, 2, 41, 16, 49, 37, 9, 47, 36, 11, 10]
# Average Precision: 0.3333
# Precision: 0.0588
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Pressure on terrorists to surrender
# Documentos relevantes esperados: [3]
# Documentos recuperados ordenados: [3]
# Average Precision: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Staff training on anti-trafficking measures at a hotel
# Documentos relevantes esperados: [4]
# Documentos recuperados ordenados: [4, 21, 38, 6, 30, 19, 17, 0, 42, 43, 23, 22, 32, 33, 18, 11]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Technology against sex trafficking in India
# Documentos relevantes esperados: [4]
# Documentos recuperados ordenados: [4, 21, 16, 6, 38, 29, 44, 18, 23, 28, 46, 2, 7, 10]
# Average Precision: 1.0000
# Precision: 0.0714
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Suspicious death under police custody
# Documentos relevantes esperados: [5]
# Documentos recuperados ordenados: [5, 4, 43, 50, 7, 39, 27, 49, 30, 2, 34, 21, 3, 16, 24, 41]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Suspicions of police abuse in interrogations
# Documentos relevantes esperados: [5]
# Documentos recuperados ordenados: [16, 34, 39, 27, 5, 49, 30, 7, 4, 21, 3, 24, 41]
# Average Precision: 0.2000
# Precision: 0.0769
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Reduced compensation due to shared negligence
# Documentos relevantes esperados: [6]
# Documentos recuperados ordenados: [6, 22, 28, 48, 34, 1, 7, 45, 20, 5, 41, 11, 13, 19]
# Average Precision: 1.0000
# Precision: 0.0714
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Pedestrian responsibility in traffic accidents
# Documentos relevantes esperados: [6]
# Documentos recuperados ordenados: [21, 6, 4, 23]
# Average Precision: 0.5000
# Precision: 0.2500
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Lynching due to mass hysteria over haircut
# Documentos relevantes esperados: [7]
# Documentos recuperados ordenados: [7, 20, 28, 34, 45]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Cases of mass hysteria in rural India
# Documentos relevantes esperados: [7]
# Documentos recuperados ordenados: [7, 50, 20, 25, 16, 29, 4, 44, 18, 28, 46, 2, 10]
# Average Precision: 1.0000
# Precision: 0.0769
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Helicopter accident due to low altitude flight
# Documentos relevantes esperados: [8]
# Documentos recuperados ordenados: [8, 24, 23, 26, 28, 34, 7, 45, 20, 33, 29]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Human errors in air accidents in India
# Documentos relevantes esperados: [8]
# Documentos recuperados ordenados: [38, 23, 13, 44, 16, 4, 29, 43, 18, 48, 26, 8, 46, 28, 2, 7, 10]
# Average Precision: 0.0833
# Precision: 0.0588
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Symbolic protest over tomato inflation
# Documentos relevantes esperados: [9]
# Documentos recuperados ordenados: [9, 22, 39]
# Average Precision: 1.0000
# Precision: 0.3333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Impact of tomato prices in India
# Documentos relevantes esperados: [9]
# Documentos recuperados ordenados: [9, 28, 4, 16, 29, 44, 18, 46, 2, 7, 10]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Recovery of surplus food to feed those in need
# Documentos relevantes esperados: [10]
# Documentos recuperados ordenados: [10, 20, 13, 29, 21, 9, 8, 1, 25, 4, 45]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Regulation for food banks in India
# Documentos relevantes esperados: [10]
# Documentos recuperados ordenados: [10, 16, 29, 44, 18, 13, 28, 46, 2, 7, 4]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Fake job offer from Google to a teenager
# Documentos relevantes esperados: [11]
# Documentos recuperados ordenados: [11, 12, 5, 36, 19, 16, 22]
# Average Precision: 1.0000
# Precision: 0.1429
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Fake offers and hoax traumatize young people
# Documentos relevantes esperados: [11]
# Documentos recuperados ordenados: [11]
# Average Precision: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Tax exemption for offering free parking in Gurugram
# Documentos relevantes esperados: [12]
# Documentos recuperados ordenados: [12, 15, 10, 13]
# Average Precision: 1.0000
# Precision: 0.2500
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Decision of commercial buildings not to offer free parking
# Documentos relevantes esperados: [12]
# Documentos recuperados ordenados: [12, 14, 11, 39, 36, 50, 15, 44, 34, 22]
# Average Precision: 1.0000
# Precision: 0.1000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Genetic editing of human embryos to prevent diseases
# Documentos relevantes esperados: [13]
# Documentos recuperados ordenados: [13, 43, 4, 23, 38, 29]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Risks and ethical debate on genetic editing of embryos
# Documentos relevantes esperados: [13]
# Documentos recuperados ordenados: [13, 29]
# Average Precision: 1.0000
# Precision: 0.5000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Dangerous buildings in Delhi under government control
# Documentos relevantes esperados: [14]
# Documentos recuperados ordenados: [14, 38, 25, 21, 8, 0, 42, 44, 5, 17, 22, 19, 12, 6, 39, 16, 7, 35, 28, 18, 30, 2, 43, 36, 10, 4, 11]
# Average Precision: 1.0000
# Precision: 0.0370
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Annual review of unsafe buildings by municipal authorities
# Documentos relevantes esperados: [14]
# Documentos recuperados ordenados: [14, 12, 30, 21, 11, 24]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Rajya Sabha elections with NOTA option in Gujarat
# Documentos relevantes esperados: [15]
# Documentos recuperados ordenados: [15, 12, 44, 40, 14, 19, 0, 42, 29]
# Average Precision: 1.0000
# Precision: 0.1111
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Supreme Court maintains NOTA option in Gujarat elections
# Documentos relevantes esperados: [15]
# Documentos recuperados ordenados: [15, 6, 12, 0, 42, 40, 11, 19, 10, 29]
# Average Precision: 1.0000
# Precision: 0.1000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Indian athlete accused of sexual abuse in the US
# No hay documentos relevantes etiquetados para esta consulta. Se omite en MAP.
# ------------------------------------------------------------
# Consulta: Legal case against Indian athlete in the U.S. for sexual abuse
# Documentos relevantes esperados: [16]
# Documentos recuperados ordenados: [16, 34, 41, 50, 4, 20, 9, 7, 3, 5, 36]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: False bomb alarm at Delhi airport due to Maruti parts
# Documentos relevantes esperados: [17]
# Documentos recuperados ordenados: [17, 38, 7, 28, 34, 6, 14, 21, 41, 45, 5, 19, 23, 29, 44, 18, 30, 2, 16, 22, 10]
# Average Precision: 1.0000
# Precision: 0.0476
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Bomb squad verifies suspicion at Delhi airport
# Documentos relevantes esperados: [17]
# Documentos recuperados ordenados: [17, 19]
# Average Precision: 1.0000
# Precision: 0.5000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Controversial virginity questionnaire at IGIMS Bihar
# Documentos relevantes esperados: [18]
# Documentos recuperados ordenados: [18, 2, 13]
# Average Precision: 1.0000
# Precision: 0.3333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Health minister's defense of questionnaire at IGIMS
# Documentos relevantes esperados: [18]
# Documentos recuperados ordenados: [18, 2, 26, 36, 39, 45, 14, 34, 44, 37, 0, 42, 25, 10, 19, 13]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Confusion of Norwegian anti-immigrant group over seats and burqas
# Documentos relevantes esperados: [19]
# Documentos recuperados ordenados: [19, 4, 30, 44, 22]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Reactions and racism in Norwegian group after photo of empty seats
# Documentos relevantes esperados: [19]
# Documentos recuperados ordenados: [19, 4, 44, 20, 2, 23]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Baby born with malformed twin inside in Maharashtra
# Documentos relevantes esperados: [20]
# Documentos recuperados ordenados: [20, 4, 29, 5, 3, 8]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Rare case of monozygotic twin pregnancy with fetus in fetu
# Documentos relevantes esperados: [20]
# Documentos recuperados ordenados: [20, 50, 7, 48, 12, 23, 16, 5, 36, 41, 4]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Ban on street vendors near AIIMS and Safdarjung in Delhi
# Documentos relevantes esperados: [21]
# Documentos recuperados ordenados: [21, 18, 43, 47, 14, 19, 38, 5, 17, 6, 29, 39, 7, 44, 30, 8, 20, 2, 16, 24, 22, 10]
# Average Precision: 1.0000
# Precision: 0.0455
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Measures to improve traffic and accessibility in Delhi hospitals
# Documentos relevantes esperados: [21]
# Documentos recuperados ordenados: [21, 38, 4, 6, 14, 5, 17, 23, 7, 44, 18, 30, 2, 16, 22, 10]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Farmers’ protest in Noida for compensation and release of arrested protesters
# Documentos relevantes esperados: [22]
# Documentos recuperados ordenados: [22, 6, 39, 47, 16, 11, 9, 7, 23, 48, 34, 43, 5, 4, 13, 29]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Dialogue between farmers and authorities on compensation and protests in Noida
# Documentos relevantes esperados: [22]
# Documentos recuperados ordenados: [22, 30, 6, 21, 11, 24]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Near collision incident of Air Canada plane at San Francisco airport
# Documentos relevantes esperados: [23]
# Documentos recuperados ordenados: [23, 24, 38, 17, 49, 44, 6, 8, 29, 25, 39, 48, 11, 26, 20, 21]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Confusion among Air Canada pilots and safety systems at SF airport
# Documentos relevantes esperados: [23]
# Documentos recuperados ordenados: [23, 8, 38, 17, 6, 44, 10, 43, 48, 26, 16, 3, 19, 29]
# Average Precision: 1.0000
# Precision: 0.0714
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Emergency landing of a plane that killed two beachgoers in Lisbon
# Documentos relevantes esperados: [24]
# Documentos recuperados ordenados: [24, 23, 22, 21, 8, 31, 25, 29, 30, 7, 39, 3, 5]
# Average Precision: 1.0000
# Precision: 0.0769
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Air accident on Portuguese beach with fatal victims
# Documentos relevantes esperados: [24]
# Documentos recuperados ordenados: [24, 6, 23, 8, 38, 44, 43, 4, 32, 34, 48, 26]
# Average Precision: 1.0000
# Precision: 0.0833
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Fuel blockade for UN humanitarian flights in Yemen by Saudi coalition
# Documentos relevantes esperados: [25]
# Documentos recuperados ordenados: [25, 23, 40, 43]
# Average Precision: 1.0000
# Precision: 0.2500
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Successful test of Minuteman 3 intercontinental ballistic missile in California
# Documentos relevantes esperados: [26]
# Documentos recuperados ordenados: [26, 40, 43, 1, 27]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Geopolitical context and missile tests in the U.S. amid North Korea threats
# Documentos relevantes esperados: [26]
# Documentos recuperados ordenados: [26, 40, 43, 5, 36, 14, 4]
# Average Precision: 1.0000
# Precision: 0.1429
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: German hiker found frozen in Swiss glacier after 30 years missing
# Documentos relevantes esperados: [27]
# Documentos recuperados ordenados: [27, 20, 5, 50, 19, 17, 8, 33, 28, 34, 40, 32, 13, 7, 18, 14, 38, 6, 12, 29]
# Average Precision: 1.0000
# Precision: 0.0500
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Human remains found in Swiss glacier decades after disappearance
# Documentos relevantes esperados: [27]
# Documentos recuperados ordenados: [27, 13, 5, 28, 43, 48, 7, 20, 4, 38, 0, 42, 11]
# Average Precision: 1.0000
# Precision: 0.0769
# Recall: 1.0000
# ------------------------------------------------------------

# %%
def mostrar_metricas_finales_sin_sinonimos(map_scores, map_precision, map_recall):
    print(f"\n======= MÉTRICAS FINALES SIN SINÓNIMOS =======")

    if map_scores:
        mean_ap = sum(map_scores) / len(map_scores)
        print(f"Mean Average Precision (MAP): {mean_ap:.4f}")
    else:
        print("No se pudo calcular MAP porque ninguna consulta tenía documentos relevantes.")

    print(f"\n========================")

    if map_precision:
        avg_precision = sum(map_precision) / len(map_precision)
        print(f"Average Precision: {avg_precision:.4f}")
    else:
        print("No se pudo calcular la precisión porque ninguna consulta tenía documentos relevantes.")

    print(f"\n========================")

    if map_recall:
        avg_recall = sum(map_recall) / len(map_recall)
        print(f"Average Recall: {avg_recall:.4f}")
    else:
        print("No se pudo calcular el recall porque ninguna consulta tenía documentos relevantes.")

# %%
# Calcular MAP general para el caso en el que no se usan sinónimos

mostrar_metricas_finales_sin_sinonimos(map_scores, map_precision, map_recall)
# Out:
# ======= MÉTRICAS FINALES SIN SINÓNIMOS =======
# Mean Average Precision (MAP): 0.9006
#
# ========================
# Average Precision: 0.1739
#
# ========================
# Average Recall: 0.9574

# %%
#Calculo de similitudes para cada consulta haciendo uso de sinónimos

corpus_normalizado = lectura_normalizada_corpus_sinonimos()
corpus_normalizado_reducido = corpus_normalizado[0:51]
map_scores, map_precision, map_recall = evaluar_consultas_por_similitud(consultas, corpus_normalizado_reducido)
# Out:
# Consulta: News about Donald Trump
# Documentos relevantes esperados: [32, 33, 35, 37, 40, 43]
# Documentos recuperados ordenados: [32, 35, 37, 40, 33, 43, 16, 9, 7, 11, 20, 2, 8, 36, 19, 46, 3, 6, 12, 13, 42, 0, 18, 5, 25, 24, 39, 4, 47, 29]
# Average Precision: 1.0000
# Precision: 0.2000
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Information about films, series and shows
# Documentos relevantes esperados: [41, 46, 47, 48]
# Documentos recuperados ordenados: [34, 47, 46, 28, 10, 37, 41, 18, 25, 11, 36, 23, 35, 33, 39, 45, 26, 1, 5, 3, 38, 13, 8, 12, 29, 4]
# Average Precision: 0.5317
# Precision: 0.1154
# Recall: 0.7500
# ------------------------------------------------------------
# Consulta: Cases related to racism and hindu culture in offices
# Documentos relevantes esperados: [42]
# Documentos recuperados ordenados: [0, 42, 45, 50, 20, 19, 7, 5, 25, 1, 36, 24, 4, 46, 32, 11, 21, 33]
# Average Precision: 0.5000
# Precision: 0.0556
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Data on economy and finance
# Documentos relevantes esperados: [44, 45]
# Documentos recuperados ordenados: [44, 18, 45, 49, 26, 38, 23, 31, 29, 5, 25, 41, 33, 22, 11]
# Average Precision: 0.8333
# Precision: 0.1333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Topics on feminism and women's rights
# Documentos relevantes esperados: [34, 36, 47]
# Documentos recuperados ordenados: [1, 36, 7, 42, 0, 22, 31, 18, 13, 39, 19, 4]
# Average Precision: 0.5000
# Precision: 0.0833
# Recall: 0.3333
# ------------------------------------------------------------
# Consulta: Security forces and police operations
# Documentos relevantes esperados: [30, 31, 39, 49]
# Documentos recuperados ordenados: [3, 31, 30, 5, 39, 17, 49, 27, 34, 7, 8, 6, 9, 33, 23, 4, 13, 21, 35, 46, 26, 50, 40, 24, 43, 19, 29, 25, 15, 41, 47, 16]
# Average Precision: 0.5845
# Precision: 0.1250
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Political situation in the United States (US)
# Documentos relevantes esperados: [32, 33, 35, 40, 43]
# Documentos recuperados ordenados: [43, 40, 16, 26, 35, 39, 15, 9, 11, 25, 0, 37, 3, 36, 42, 22, 13, 32, 7, 48, 19, 14, 33, 4, 12, 49, 29, 31, 2, 24, 44, 21, 50, 45, 46, 20, 5, 34, 10, 23, 8, 27, 6, 17, 1, 41]
# Average Precision: 0.6079
# Precision: 0.1087
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Politics in India (Delhi)
# Documentos relevantes esperados: [36, 39, 42, 44]
# Documentos recuperados ordenados: [14, 16, 29, 44, 5, 21, 46, 38, 42, 0, 18, 17, 28, 7, 2, 6, 25, 10, 22, 30, 4, 35, 12, 36, 43, 11, 19]
# Average Precision: 0.1991
# Precision: 0.1111
# Recall: 0.7500
# ------------------------------------------------------------
# Consulta: Armed conflicts in which ballistic missiles have been used
# Documentos relevantes esperados: [40]
# Documentos recuperados ordenados: [26, 40, 43, 20, 50, 39, 18, 1, 41, 15, 36, 5, 16, 44, 2, 13, 4, 8, 32, 21, 33, 48, 10, 3, 45, 28, 14, 34, 12, 7, 23, 9, 11, 22]
# Average Precision: 0.5000
# Precision: 0.0294
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Environment, ecology and health
# Documentos relevantes esperados: [38, 39]
# Documentos recuperados ordenados: [39, 2, 18, 20, 45, 29, 34, 37, 25, 33, 10, 21, 13]
# Average Precision: 1.0000
# Precision: 0.0769
# Recall: 0.5000
# ------------------------------------------------------------
# Consulta: Ailments caused by pollutant
# Documentos relevantes esperados: [38]
# Documentos recuperados ordenados: [38, 21, 35, 41, 11, 20, 13, 6, 4, 44, 9, 1, 47, 39, 50, 25, 24, 30, 5, 37, 16, 28, 27, 49, 34, 7, 19, 45, 42, 0, 15, 8, 29, 10, 22, 23, 33]
# Average Precision: 1.0000
# Precision: 0.0270
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Imposition of Rakshabandhan religious celebration in offices
# Documentos relevantes esperados: [0]
# Documentos recuperados ordenados: [0, 42, 34, 12, 2, 44, 18, 9]
# Average Precision: 1.0000
# Precision: 0.1250
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Controversies over mandatory labor regulations related to religion in the workplace
# Documentos relevantes esperados: [0]
# Documentos recuperados ordenados: [0, 42, 14, 4, 5, 45, 6, 44, 36, 18, 2, 39, 49, 19, 13, 37, 38, 9, 34, 22, 32, 48, 41, 10, 21, 29, 23]
# Average Precision: 1.0000
# Precision: 0.0370
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Criticism of famous women after divorce
# Documentos relevantes esperados: [1]
# Documentos recuperados ordenados: [1, 19, 33, 36, 29, 7, 37, 42, 0, 45, 22, 31, 18, 13, 39, 4]
# Average Precision: 1.0000
# Precision: 0.0625
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Misogyny on social media toward successful and independent woman
# Documentos relevantes esperados: [1]
# Documentos recuperados ordenados: [1, 5, 36, 7, 39, 0, 42, 21, 3, 4, 24, 11, 46, 22, 26, 43, 2, 45, 16, 14, 41, 18, 19, 6, 20, 32, 27, 33, 47, 13, 29]
# Average Precision: 1.0000
# Precision: 0.0323
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Controversy over an inappropriate institutional form
# Documentos relevantes esperados: [2]
# Documentos recuperados ordenados: [2, 18, 16, 13, 20, 49, 44, 21, 41, 5, 34, 12, 45, 32, 39, 1, 11, 23, 27, 35, 14, 24, 6, 4, 22, 47, 36, 42, 0, 15, 48, 3, 8, 25, 9, 33, 7, 19, 10, 29]
# Average Precision: 1.0000
# Precision: 0.0250
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Woman reports inappropriate questions on a form asking if she was a virgin or unmarried
# Documentos relevantes esperados: [2]
# Documentos recuperados ordenados: [2, 18, 5, 1, 7, 16, 36, 4, 3, 13, 20, 34, 39, 22, 33, 46, 9, 24, 44, 49, 19, 41, 21, 47, 45, 32, 8, 42, 12, 0, 14, 48, 11, 23, 30, 25, 35, 27, 15, 50, 6, 10, 40, 43, 29]
# Average Precision: 1.0000
# Precision: 0.0222
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Death of wanted terrorists in Kashmir
# Documentos relevantes esperados: [3]
# Documentos recuperados ordenados: [31, 3, 30, 19, 5, 16, 7, 43, 24, 2, 23, 41, 15, 4, 28, 35, 37, 8, 25, 46, 13, 40, 9, 42, 0, 49, 45, 47, 39, 36, 1, 29, 11, 21, 10, 33]
# Average Precision: 0.5000
# Precision: 0.0278
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Pressure on terrorists to surrender
# Documentos relevantes esperados: [3]
# Documentos recuperados ordenados: [3, 33, 25, 14, 49, 7, 45]
# Average Precision: 1.0000
# Precision: 0.1429
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Staff training on anti-trafficking measures at a hotel
# Documentos relevantes esperados: [4]
# Documentos recuperados ordenados: [4, 21, 0, 6, 42, 17, 30, 19, 38, 11, 39, 32, 5, 33, 22, 50, 23, 9, 15, 45, 36, 18, 2, 41, 8, 34, 29, 43]
# Average Precision: 1.0000
# Precision: 0.0357
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Technology against sex trafficking in India
# Documentos relevantes esperados: [4]
# Documentos recuperados ordenados: [4, 21, 16, 29, 46, 28, 44, 6, 18, 1, 7, 38, 2, 39, 5, 15, 13, 10, 36, 9, 47, 45, 23, 19, 3, 41, 49, 22, 20, 37, 33]
# Average Precision: 1.0000
# Precision: 0.0323
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Suspicious death under police custody
# Documentos relevantes esperados: [5]
# Documentos recuperados ordenados: [5, 39, 7, 49, 27, 17, 30, 4, 3, 43, 34, 23, 50, 21, 22, 35, 24, 8, 31, 19, 20, 16, 46, 15, 9, 2, 41, 25, 33, 13, 1, 28, 48, 40, 42, 0, 37, 45, 29]
# Average Precision: 1.0000
# Precision: 0.0256
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Suspicions of police abuse in interrogations
# Documentos relevantes esperados: [5]
# Documentos recuperados ordenados: [39, 5, 16, 34, 49, 27, 7, 30, 3, 23, 1, 4, 21, 8, 35, 17, 24, 13, 43, 19, 41]
# Average Precision: 0.5000
# Precision: 0.0476
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Reduced compensation due to shared negligence
# Documentos relevantes esperados: [6]
# Documentos recuperados ordenados: [6, 22, 31, 28, 14, 17, 7, 43, 5, 41, 36, 26, 3, 34, 40, 45, 30, 13, 1, 20, 48, 18, 2, 38, 24, 29, 10, 32, 12, 47, 8, 11, 19, 33]
# Average Precision: 1.0000
# Precision: 0.0294
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Pedestrian responsibility in traffic accidents
# Documentos relevantes esperados: [6]
# Documentos recuperados ordenados: [21, 4, 6, 36, 45, 23]
# Average Precision: 0.3333
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Lynching due to mass hysteria over haircut
# Documentos relevantes esperados: [7]
# Documentos recuperados ordenados: [7, 31, 28, 43, 14, 36, 50, 19, 41, 5, 3, 34, 24, 32, 40, 26, 29, 13, 10, 25, 30, 46, 2, 8, 42, 0, 20, 15, 38, 16, 45, 11, 21, 4, 33]
# Average Precision: 1.0000
# Precision: 0.0286
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Cases of mass hysteria in rural India
# Documentos relevantes esperados: [7]
# Documentos recuperados ordenados: [7, 50, 16, 29, 25, 20, 4, 46, 19, 28, 44, 18, 10, 2, 13, 32, 41, 40, 12, 24, 36, 42, 0, 43, 15, 38, 11, 21, 33]
# Average Precision: 1.0000
# Precision: 0.0345
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Helicopter accident due to low altitude flight
# Documentos relevantes esperados: [8]
# Documentos recuperados ordenados: [8, 23, 24, 26, 25, 7, 20, 31, 28, 43, 14, 36, 5, 40, 3, 34, 29, 15, 45, 33, 46, 41, 32, 30, 1, 19, 2, 35, 48, 50, 42, 0, 37, 38, 16, 44, 49, 13, 11, 4, 10, 47]
# Average Precision: 1.0000
# Precision: 0.0238
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Human errors in air accidents in India
# Documentos relevantes esperados: [8]
# Documentos recuperados ordenados: [29, 16, 23, 44, 38, 46, 18, 28, 13, 24, 49, 3, 2, 50, 8, 25, 7, 31, 1, 4, 5, 33, 48, 17, 20, 26, 43, 36, 45, 42, 10, 0, 40, 39, 9, 19, 22, 15, 30, 21, 41, 6, 47]
# Average Precision: 0.0667
# Precision: 0.0233
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Symbolic protest over tomato inflation
# Documentos relevantes esperados: [9]
# Documentos recuperados ordenados: [9, 22, 39]
# Average Precision: 1.0000
# Precision: 0.3333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Impact of tomato prices in India
# Documentos relevantes esperados: [9]
# Documentos recuperados ordenados: [9, 16, 29, 46, 28, 4, 44, 18, 41, 2, 13, 10, 45, 7, 37, 47, 33]
# Average Precision: 1.0000
# Precision: 0.0588
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Recovery of surplus food to feed those in need
# Documentos relevantes esperados: [10]
# Documentos recuperados ordenados: [10, 17, 44, 20, 3, 41, 30, 13, 39, 45, 42, 22, 0, 27, 49, 36, 47, 32, 2, 5, 15, 34, 8, 37, 1, 12, 21, 16, 19, 24, 18, 33, 50, 9, 11, 48, 38, 23, 25, 29, 14, 7, 40, 43, 4]
# Average Precision: 1.0000
# Precision: 0.0222
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Regulation for food banks in India
# Documentos relevantes esperados: [10]
# Documentos recuperados ordenados: [10, 16, 29, 44, 46, 18, 15, 28, 2, 7, 6, 43, 20, 13, 45, 30, 42, 0, 5, 3, 4, 37, 41, 39]
# Average Precision: 1.0000
# Precision: 0.0417
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Fake job offer from Google to a teenager
# Documentos relevantes esperados: [11]
# Documentos recuperados ordenados: [11, 44, 45, 12, 10, 5, 4, 36, 2, 42, 19, 0, 16, 47, 22, 1, 48, 21, 18, 35, 23, 49, 40, 15, 37, 38, 25, 9, 41, 39, 24, 7, 13, 33]
# Average Precision: 1.0000
# Precision: 0.0294
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Fake offers and hoax traumatize young people
# Documentos relevantes esperados: [11]
# Documentos recuperados ordenados: [45, 33, 11, 41]
# Average Precision: 0.3333
# Precision: 0.2500
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Tax exemption for offering free parking in Gurugram
# Documentos relevantes esperados: [12]
# Documentos recuperados ordenados: [12, 11, 29, 16, 45, 24, 4, 5, 44, 21, 22, 2, 17, 33, 48, 15, 47, 14, 49, 34, 7, 10, 23, 26, 1, 13, 6]
# Average Precision: 1.0000
# Precision: 0.0370
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Decision of commercial buildings not to offer free parking
# Documentos relevantes esperados: [12]
# Documentos recuperados ordenados: [14, 12, 39, 36, 50, 44, 15, 45, 34, 11, 21, 10, 24, 4, 22, 5, 48, 33, 49, 47, 1, 7, 13, 42, 0, 18, 35, 19, 40, 37, 38, 25, 9, 41]
# Average Precision: 0.5000
# Precision: 0.0294
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Genetic editing of human embryos to prevent diseases
# Documentos relevantes esperados: [13]
# Documentos recuperados ordenados: [13, 7, 49, 37, 3, 50, 25, 29, 33, 18, 1, 47, 43, 2, 20, 24, 5, 39, 28, 4, 23, 9, 41, 45, 11, 19, 22, 40, 36, 15, 38, 16, 21, 8]
# Average Precision: 1.0000
# Precision: 0.0294
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Risks and ethical debate on genetic editing of embryos
# Documentos relevantes esperados: [13]
# Documentos recuperados ordenados: [13, 33, 29, 36, 38, 39]
# Average Precision: 1.0000
# Precision: 0.1667
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Dangerous buildings in Delhi under government control
# Documentos relevantes esperados: [14]
# Documentos recuperados ordenados: [14, 38, 21, 5, 42, 44, 0, 17, 22, 30, 25, 6, 7, 18, 19, 2, 15, 11, 43, 12, 39, 16, 10, 50, 36, 23, 8, 45, 48, 13, 4, 35, 9, 47, 24, 37, 33, 46, 20, 28, 49, 29, 34, 40, 1, 41]
# Average Precision: 1.0000
# Precision: 0.0217
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Annual review of unsafe buildings by municipal authorities
# Documentos relevantes esperados: [14]
# Documentos recuperados ordenados: [14, 12, 38, 21, 42, 0, 19, 30, 25, 44, 43, 11, 22, 35, 40, 36, 5, 16, 9, 24, 6, 4]
# Average Precision: 1.0000
# Precision: 0.0455
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Rajya Sabha elections with NOTA option in Gujarat
# Documentos relevantes esperados: [15]
# Documentos recuperados ordenados: [15, 44, 14, 42, 0, 19, 11, 40, 32, 36, 20, 29, 49, 12, 13, 50, 47, 5, 18, 3, 9, 10, 33]
# Average Precision: 1.0000
# Precision: 0.0435
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Supreme Court maintains NOTA option in Gujarat elections
# Documentos relevantes esperados: [15]
# Documentos recuperados ordenados: [15, 6, 50, 36, 22, 39, 5, 42, 0, 11, 41, 19, 7, 47, 40, 32, 20, 18, 13, 10, 3, 49, 29, 9, 12, 17, 46, 21, 1, 43, 2, 25, 33]
# Average Precision: 1.0000
# Precision: 0.0303
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Indian athlete accused of sexual abuse in the US
# Documentos relevantes esperados: [16]
# Documentos recuperados ordenados: [16, 39, 34, 4, 43, 41, 49, 37, 36, 25, 7, 33]
# Average Precision: 1.0000
# Precision: 0.0833
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Legal case against Indian athlete in the U.S. for sexual abuse
# Documentos relevantes esperados: [16]
# Documentos recuperados ordenados: [16, 39, 4, 9, 15, 34, 20, 50, 14, 41, 3, 7, 25, 13, 5, 19, 49, 1, 2, 42, 0, 35, 37, 28, 40, 27, 29, 21, 43, 48, 45, 36, 33, 38, 8, 6, 24]
# Average Precision: 1.0000
# Precision: 0.0270
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: False bomb alarm at Delhi airport due to Maruti parts
# Documentos relevantes esperados: [17]
# Documentos recuperados ordenados: [17, 14, 38, 5, 40, 7, 21, 36, 31, 28, 6, 43, 2, 29, 41, 3, 34, 30, 26, 44, 8, 23, 4, 24, 18, 19, 10, 22, 16, 45]
# Average Precision: 1.0000
# Precision: 0.0333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Bomb squad verifies suspicion at Delhi airport
# Documentos relevantes esperados: [17]
# Documentos recuperados ordenados: [17, 5, 40, 7, 20, 35, 47, 19, 29, 39, 33]
# Average Precision: 1.0000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Controversial virginity questionnaire at IGIMS Bihar
# Documentos relevantes esperados: [18]
# Documentos recuperados ordenados: [18, 2, 13]
# Average Precision: 1.0000
# Precision: 0.3333
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Health minister's defense of questionnaire at IGIMS
# Documentos relevantes esperados: [18]
# Documentos recuperados ordenados: [18, 26, 2, 14, 44, 36, 42, 0, 38, 39, 19, 16, 20, 5, 33, 45, 34, 37, 25, 10, 21, 13]
# Average Precision: 1.0000
# Precision: 0.0455
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Confusion of Norwegian anti-immigrant group over seats and burqas
# Documentos relevantes esperados: [19]
# Documentos recuperados ordenados: [19, 4, 30, 44, 36, 22, 5, 26, 7, 16, 25, 35, 49, 33, 42, 0, 48, 2, 41, 6, 45, 13, 29]
# Average Precision: 1.0000
# Precision: 0.0435
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Reactions and racism in Norwegian group after photo of empty seats
# Documentos relevantes esperados: [19]
# Documentos recuperados ordenados: [19, 4, 44, 36, 33, 9, 48, 2, 23, 5, 1, 20, 26, 24, 7, 25, 16, 35, 49, 42, 0, 41, 6, 45, 13, 29]
# Average Precision: 1.0000
# Precision: 0.0385
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Baby born with malformed twin inside in Maharashtra
# Documentos relevantes esperados: [20]
# Documentos recuperados ordenados: [20, 4, 1, 29, 42, 0, 45, 8, 18, 43, 33, 6, 11, 25, 5, 3, 23]
# Average Precision: 1.0000
# Precision: 0.0588
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Rare case of monozygotic twin pregnancy with fetus in fetu
# Documentos relevantes esperados: [20]
# Documentos recuperados ordenados: [20, 50, 7, 4, 27, 25, 5, 48, 16, 12, 22, 13, 9, 1, 23, 47, 37, 2, 28, 39, 19, 36, 15, 3, 38, 8, 41, 24, 6, 21, 45]
# Average Precision: 1.0000
# Precision: 0.0323
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Ban on street vendors near AIIMS and Safdarjung in Delhi
# Documentos relevantes esperados: [21]
# Documentos recuperados ordenados: [21, 14, 18, 43, 7, 5, 38, 30, 22, 17, 19, 47, 6, 44, 29, 39, 13, 2, 10, 23, 8, 20, 16, 24, 35, 34, 32, 45, 37, 25, 4]
# Average Precision: 1.0000
# Precision: 0.0323
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Measures to improve traffic and accessibility in Delhi hospitals
# Documentos relevantes esperados: [21]
# Documentos recuperados ordenados: [21, 4, 14, 38, 17, 5, 6, 2, 9, 33, 44, 7, 24, 30, 18, 23, 45, 22, 10, 29, 16]
# Average Precision: 1.0000
# Precision: 0.0476
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Farmers’ protest in Noida for compensation and release of arrested protesters
# Documentos relevantes esperados: [22]
# Documentos recuperados ordenados: [22, 6, 11, 39, 12, 21, 15, 16, 9, 47, 49, 45, 33, 48, 41, 7, 17, 50, 37, 23, 42, 4, 0, 1, 18, 32, 5, 13, 3, 40, 31, 43, 36, 34, 46, 29, 30, 20, 10, 2, 38, 25, 19]
# Average Precision: 1.0000
# Precision: 0.0233
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Dialogue between farmers and authorities on compensation and protests in Noida
# Documentos relevantes esperados: [22]
# Documentos recuperados ordenados: [22, 6, 42, 0, 30, 25, 44, 43, 11, 21, 35, 12, 40, 36, 5, 16, 9, 24, 4, 19]
# Average Precision: 1.0000
# Precision: 0.0500
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Near collision incident of Air Canada plane at San Francisco airport
# Documentos relevantes esperados: [23]
# Documentos recuperados ordenados: [23, 24, 25, 17, 49, 6, 30, 38, 8, 39, 44, 40, 29, 13, 31, 48, 26, 45, 3, 20, 42, 0, 11, 47, 10, 9, 21, 33, 36, 35, 14, 34, 4, 46, 32, 37, 43, 5, 7, 41, 19, 22]
# Average Precision: 1.0000
# Precision: 0.0238
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Confusion among Air Canada pilots and safety systems at SF airport
# Documentos relevantes esperados: [23]
# Documentos recuperados ordenados: [23, 8, 17, 38, 6, 44, 3, 50, 31, 10, 43, 5, 24, 36, 48, 26, 16, 42, 29, 0, 19, 9, 13, 46, 40, 45, 30, 41, 39, 4, 33]
# Average Precision: 1.0000
# Precision: 0.0323
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Emergency landing of a plane that killed two beachgoers in Lisbon
# Documentos relevantes esperados: [24]
# Documentos recuperados ordenados: [24, 23, 25, 21, 31, 22, 29, 27, 4, 8, 30, 39, 43, 26, 19, 7, 14, 16, 9, 12, 40, 13, 3, 10, 5, 36, 38, 11, 34, 50, 37, 18, 2, 41, 33]
# Average Precision: 1.0000
# Precision: 0.0286
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Air accident on Portuguese beach with fatal victims
# Documentos relevantes esperados: [24]
# Documentos recuperados ordenados: [24, 6, 23, 38, 8, 43, 32, 4, 34, 44, 31, 48, 17, 26, 3, 42, 0, 9, 36, 46, 40, 45, 30, 5, 41, 39, 33]
# Average Precision: 1.0000
# Precision: 0.0370
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Fuel blockade for UN humanitarian flights in Yemen by Saudi coalition
# Documentos relevantes esperados: [25]
# Documentos recuperados ordenados: [25, 33, 40, 23, 22, 43, 45, 19, 37, 21, 13, 16, 6]
# Average Precision: 1.0000
# Precision: 0.0769
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Successful test of Minuteman 3 intercontinental ballistic missile in California
# Documentos relevantes esperados: [26]
# Documentos recuperados ordenados: [26, 40, 43, 1, 13, 27, 6, 15, 47, 24, 34, 4, 48, 37, 3, 39, 21, 33]
# Average Precision: 1.0000
# Precision: 0.0556
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Geopolitical context and missile tests in the U.S. amid North Korea threats
# Documentos relevantes esperados: [26]
# Documentos recuperados ordenados: [43, 26, 40, 14, 5, 36, 4, 42, 0, 6, 29]
# Average Precision: 0.5000
# Precision: 0.0909
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: German hiker found frozen in Swiss glacier after 30 years missing
# Documentos relevantes esperados: [27]
# Documentos recuperados ordenados: [27, 20, 19, 5, 3, 16, 4, 7, 6, 33, 17, 2, 50, 11, 37, 48, 24, 13, 9, 28, 45, 41, 8, 34, 43, 47, 15, 14, 18, 21, 40, 38, 32, 25, 1, 29, 23, 46, 31, 36, 30, 12, 42, 0, 22]
# Average Precision: 1.0000
# Precision: 0.0222
# Recall: 1.0000
# ------------------------------------------------------------
# Consulta: Human remains found in Swiss glacier decades after disappearance
# Documentos relevantes esperados: [27]
# Documentos recuperados ordenados: [27, 18, 5, 28, 2, 26, 49, 13, 4, 29, 50, 25, 33, 15, 43, 20, 7, 1, 48, 3, 24, 36, 40, 32, 8, 45, 34, 46, 39, 38, 31, 14, 19, 21, 22, 6, 42, 0, 16, 47, 11, 23]
# Average Precision: 1.0000
# Precision: 0.0238
# Recall: 1.0000
# ------------------------------------------------------------

# %%
def mostrar_metricas_finales_con_sinonimos(map_scores, map_precision, map_recall):
    print(f"\n======= MÉTRICAS FINALES CON SINÓNIMOS =======")

    if map_scores:
        mean_ap = sum(map_scores) / len(map_scores)
        print(f"Mean Average Precision (MAP): {mean_ap:.4f}")
    else:
        print("No se pudo calcular MAP porque ninguna consulta tenía documentos relevantes.")

    print(f"\n========================")

    if map_precision:
        avg_precision = sum(map_precision) / len(map_precision)
        print(f"Average Precision: {avg_precision:.4f}")
    else:
        print("No se pudo calcular la precisión porque ninguna consulta tenía documentos relevantes.")

    print(f"\n========================")

    if map_recall:
        avg_recall = sum(map_recall) / len(map_recall)
        print(f"Average Recall: {avg_recall:.4f}")
    else:
        print("No se pudo calcular el recall porque ninguna consulta tenía documentos relevantes.")

# %%
# Calcular MAP general para el caso en el que se usan sinónimos

mostrar_metricas_finales_con_sinonimos(map_scores, map_precision, map_recall)
# Out:
# ======= MÉTRICAS FINALES CON SINÓNIMOS =======
# Mean Average Precision (MAP): 0.8786
#
# ========================
# Average Precision: 0.0675
#
# ========================
# Average Recall: 0.9747
