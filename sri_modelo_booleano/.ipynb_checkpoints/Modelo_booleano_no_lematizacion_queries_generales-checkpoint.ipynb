# %% [markdown]
#  ## 1. Lectura de datos
#
#  Se comenzará con la lectura del corpus, en la cual no se utilizará la lematización como técnica de normalización de términos.

# %%
# !pip install nltk
import nltk

from nltk import download

download('punkt_tab')                           # Tokenización
nltk.download('averaged_perceptron_tagger')     # POS tagging
nltk.download('averaged_perceptron_tagger_eng') # POS tagging
nltk.download('wordnet')                        # WordNet lemmatizer
nltk.download('omw-1.4')                        # WordNet multilingüe
# Out:
# Requirement already satisfied: nltk in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
from nltk.corpus import stopwords
from nltk.data import path
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

path.append(".")

# %%
# !pip install contractions
import contractions
# Out:
# Requirement already satisfied: contractions in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (from textsearch>=0.0.21->contractions) (2.1.0)

# %%
import csv
import pandas as pd
from bs4 import BeautifulSoup
from pprint import pprint
import re
from bs4 import MarkupResemblesLocatorWarning
import warnings

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier

# %%
warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

# %%
palabras_vacias_ingles = stopwords.words('english')

# %%
def elimina_html(contenido):
    return BeautifulSoup(contenido).get_text()

def elimina_no_alfanumerico(contenido):
    return [re.sub(r'[^\w]', '', palabra)
            for palabra in contenido
            if re.search(r'\w', palabra)]

def expandir_constracciones(contenido):
    return contractions.fix(contenido)

def pasar_a_minuscula(contenido):
    return contenido.lower()

def limpiar_texto(texto):
    texto = re.sub(r'[^a-zA-Z0-9\s]', ' ', texto)  # Reemplaza todo lo que no es letra, espacio o número con espacio
    texto = re.sub(r'\s+', ' ', texto).strip()
    return texto

def elimina_palabras_vacias(contenido):
    return [palabra for palabra in contenido if palabra not in palabras_vacias_ingles]

# %%
def proceso_contenido(texto):
    texto = elimina_html(texto)
    texto = expandir_constracciones(texto)
    texto = pasar_a_minuscula(texto)
    texto = limpiar_texto(texto)                # Limpiar antes de tokenizar
    tokens = word_tokenize(texto)               
    tokens = elimina_no_alfanumerico(tokens)    # Limpiar tokens individuales
    tokens = elimina_palabras_vacias(tokens)
    return tokens

# %%
# Cargar CSV con codificación segura y punto y coma como separador
df = pd.read_csv("news_corpus.csv", encoding="latin-1", sep=";", quotechar='"')

# Verificar que tenga exactamente 3 columnas
assert df.shape[1] == 3, "El CSV no tiene exactamente 3 columnas. Revisa el separador o las comillas."

resultados = []

for index, fila in df.iterrows():
    autor = fila.iloc[0]
    titulo = fila.iloc[1]
    cuerpo = fila.iloc[2]

    autor_proc = proceso_contenido(autor)
    titulo_proc = proceso_contenido(titulo)
    cuerpo_proc = proceso_contenido(cuerpo)

    # Unir las tres listas en una sola lista combinada
    fila_combinada = autor_proc + titulo_proc + cuerpo_proc
    resultados.append(fila_combinada)

# %%
# Mostrar los primeros 5 documentos procesados
for i, documento in enumerate(resultados[:5]):
    print(f"Documento {i+1}:")
    print(" - Palabras:", documento)
    print()
# Out:
# Documento 1:
#  - Palabras: ['chhavi', 'tyagi', 'daman', 'diu', 'revokes', 'mandatory', 'rakshabandhan', 'offices', 'order', 'daman', 'diu', 'administration', 'wednesday', 'withdrew', 'circular', 'asked', 'women', 'staff', 'tie', 'rakhis', 'male', 'colleagues', 'order', 'triggered', 'backlash', 'employees', 'ripped', 'apart', 'social', 'media', 'union', 'territory', 'administration', 'forced', 'retreat', 'within', '24', 'hours', 'issuing', 'circular', 'made', 'compulsory', 'staff', 'celebrate', 'rakshabandhan', 'workplace', 'decided', 'celebrate', 'festival', 'rakshabandhan', 'august', '7', 'connection', 'offices', 'departments', 'shall', 'remain', 'open', 'celebrate', 'festival', 'collectively', 'suitable', 'time', 'wherein', 'lady', 'staff', 'shall', 'tie', 'rakhis', 'colleagues', 'order', 'issued', 'august', '1', 'gurpreet', 'singh', 'deputy', 'secretary', 'personnel', 'said', 'ensure', 'one', 'skipped', 'office', 'attendance', 'report', 'sent', 'government', 'next', 'evening', 'two', 'notifications', 'one', 'mandating', 'celebration', 'rakshabandhan', 'left', 'withdrawing', 'mandate', 'right', 'issued', 'daman', 'diu', 'administration', 'day', 'apart', 'circular', 'withdrawn', 'one', 'line', 'order', 'issued', 'late', 'evening', 'ut', 'department', 'personnel', 'administrative', 'reforms', 'circular', 'ridiculous', 'sensitivities', 'involved', 'government', 'dictate', 'tie', 'rakhi', 'maintain', 'professionalism', 'workplace', 'official', 'told', 'hindustan', 'times', 'earlier', 'day', 'refused', 'identified', 'notice', 'issued', 'daman', 'diu', 'administrator', 'former', 'gujarat', 'home', 'minister', 'praful', 'kodabhai', 'patel', 'direction', 'sources', 'said', 'rakshabandhan', 'celebration', 'bond', 'brothers', 'sisters', 'one', 'several', 'hindu', 'festivities', 'rituals', 'longer', 'confined', 'private', 'family', 'affairs', 'become', 'tools', 'push', 'politic', 'al', 'ideologies', '2014', 'year', 'bjp', 'stormed', 'power', 'centre', 'rashtriya', 'swayamsevak', 'sangh', 'rss', 'chief', 'mohan', 'bhagwat', 'said', 'festival', 'national', 'significance', 'celebrated', 'widely', 'protect', 'hindu', 'culture', 'live', 'values', 'enshrined', 'rss', 'ideological', 'parent', 'ruling', 'bjp', 'last', 'year', 'women', 'ministers', 'modi', 'government', 'went', 'border', 'areas', 'celebrate', 'festival', 'soldiers', 'year', 'cabinet', 'ministers', 'asked', 'go', 'constituencies', 'festival']
#
# Documento 2:
#  - Palabras: ['daisy', 'mowke', 'malaika', 'slams', 'user', 'trolled', 'divorcing', 'rich', 'man', 'special', 'numbers', 'tv', 'appearances', 'bollywood', 'actor', 'malaika', 'arora', 'khan', 'managed', 'carve', 'identity', 'actor', 'made', 'debut', 'hindi', 'film', 'industry', 'blockbuster', 'debut', 'opposite', 'shah', 'rukh', 'khan', 'chaiyya', 'chaiyya', 'dil', 'se', '1998', 'still', 'remembered', 'song', 'however', 'trolls', 'woman', 'first', 'matters', 'right', 'divorced', 'rich', 'man', 'wednesday', 'malaika', 'arora', 'shared', 'gorgeous', 'picture', 'instagram', 'follower', 'decided', 'troll', 'using', 'alumni', 'read', 'alimony', 'money', 'wear', 'short', 'clothes', 'going', 'gym', 'salon', 'little', 'know', 'munni', 'badnam', 'star', 'would', 'reply', 'perfect', 'comeback', 'take', 'look', 'interaction', 'super', 'excited', 'affiliated', 'khanna', 'jewellers', 'khannajewellerskj', 'brand', 'ambassador', 'crafted', 'perfection', 'stunning', 'statement', 'jewellery', 'must', 'every', 'jewellery', 'lover', 'khannajewellers', 'maksquad', 'hair', 'hairbypriyanka', 'stylist', 'manekaharisinghani', 'manager', 'ektakauroberoi', 'mua', 'subbu28', 'photographer', 'prasdnaik', 'post', 'shared', 'malaika', 'arora', 'khan', 'malaikaarorakhanofficial', 'aug', '2', '2017', '6', '20am', 'pdt', 'malaika', 'decided', 'reply', 'entire', 'conversation', 'proves', 'matter', 'woman', 'successful', 'attacked', 'moment', 'decides', 'step', 'bounds', 'society', 'decided', 'apart', 'successful', 'woman', 'lives', 'life', 'terms', 'malaika', 'literally', 'played', 'roles', 'traditionally', 'prescribed', 'woman', 'married', 'quite', 'early', 'son', 'raised', 'always', 'around', 'khandan', 'got', 'divorced', 'alimony', 'taunt', 'thrown', 'details', 'alimony', 'known', 'malaika', 'husband', 'arbaaz', 'khan', 'perhaps', 'family', 'couple', 'handled', 'divorce', 'utmost', 'dignity', 'vouch', 'fact', 'need', 'alimony', 'buy', 'clothes', 'short', 'choice', 'go', 'vacations', 'enjoy', 'life', 'anything', 'successful', 'ex', 'husband', 'happened', 'arbaaz', 'malaika', 'personal', 'concern', 'claim', 'malaika', 'married', 'divorced', 'arbaaz', 'money', 'hold', 'water', 'agree', 'please', 'get', 'course', 'feminism', 'others', 'playlist', 'popular', 'songs', 'follow', 'htshowbiz']
#
# Documento 3:
#  - Palabras: ['arshiya', 'chopra', 'virgin', 'corrected', 'unmarried', 'igims', 'form', 'indira', 'gandhi', 'institute', 'medical', 'sciences', 'igims', 'patna', 'amended', 'marital', 'declaration', 'form', 'thursday', 'replacing', 'word', 'virgin', 'unmarried', 'controversy', 'new', 'recruits', 'super', 'specialty', 'medical', 'institute', 'state', 'capital', 'required', 'declare', 'bachelors', 'widowers', 'virgins', 'igims', 'medical', 'superintendent', 'dr', 'manish', 'mandal', 'said', 'institute', 'director', 'dr', 'nr', 'biswas', 'held', 'meeting', 'thursday', 'morning', 'directing', 'word', 'virgin', 'marital', 'declaration', 'form', 'immediately', 'replaced', 'unmarried', 'dr', 'biswas', 'returned', 'four', 'day', 'leave', 'absence', 'earlier', 'bihar', 'health', 'minister', 'mangal', 'pandey', 'ended', 'redefining', 'meaning', 'virginity', 'attempts', 'justify', 'awkward', 'phrasing', 'question', 'form', 'following', 'public', 'furore', 'document', 'wednesday', 'minister', 'told', 'news', 'channels', 'nothing', 'wrong', 'using', 'word', 'virgin', 'simply', 'meant', 'kanya', 'kunwari', 'means', 'unmarried', 'girl', 'pandey', 'joined', 'cabinet', 'three', 'days', 'ago', 'sources', 'said', 'chief', 'minister', 'office', 'also', 'taken', 'cognizance', 'issue', 'asked', 'copy', 'form', 'even', 'asked', 'question', 'introduced', 'first', 'place', 'response', 'management', 'autonomous', 'super', 'specialty', 'health', 'facility', 'clarified', 'wednesday', 'adherence', 'central', 'civil', 'services', 'rules', 'followed', 'india', 'institute', 'medical', 'sciences', 'new', 'delhi', 'previous', 'version', 'marital', 'declaration', 'form', 'purportedly', 'asked', 'new', 'recruits', 'virgins', 'ht', 'photo', 'marital', 'declaration', 'form', 'existence', 'since', 'inception', 'institute', '1983', 'officials', 'blamed', 'faux', 'pas', 'poor', 'translation', 'part', 'individuals', 'drafted', 'document', 'word', 'virgin', 'mentioned', 'form', 'nothing', 'virginity', 'employee', 'sought', 'know', 'employees', 'marital', 'status', 'dues', 'could', 'settled', 'basis', 'declaration', 'event', 'death', 'service', 'said', 'dr', 'mandal']
#
# Documento 4:
#  - Palabras: ['sumedha', 'sehra', 'aaj', 'aapne', 'pakad', 'liya', 'let', 'man', 'dujana', 'killed', 'lashkar', 'e', 'taiba', 'kashmir', 'commander', 'abu', 'dujana', 'killed', 'encounter', 'village', 'pulwama', 'district', 'jammu', 'kashmir', 'earlier', 'week', 'dujana', 'managed', 'give', 'security', 'forces', 'slip', 'several', 'times', 'past', 'carried', 'bounty', 'rs', '15', 'lakh', 'head', 'reports', 'say', 'dujana', 'come', 'meet', 'wife', 'trapped', 'inside', 'house', 'hakripora', 'village', 'security', 'officials', 'involved', 'encounter', 'tried', 'best', 'convince', 'dujana', 'surrender', 'refused', 'reports', 'say', 'according', 'reports', 'dujana', 'rejected', 'call', 'surrender', 'army', 'officer', 'army', 'commissioned', 'local', 'start', 'telephonic', 'conversation', 'dujana', 'initiating', 'talk', 'local', 'villager', 'handed', 'phone', 'army', 'officer', 'kya', 'haal', 'hai', 'maine', 'kaha', 'kya', 'haal', 'hai', 'asked', 'dujana', 'heard', 'asking', 'officer', 'officer', 'replies', 'humara', 'haal', 'chhor', 'dujana', 'surrender', 'kyun', 'nahi', 'kar', 'deta', 'tu', 'galat', 'kar', 'rha', 'hai', 'surrender', 'married', 'girl', 'right', 'told', 'used', 'pakistani', 'agencies', 'pawn', 'dujana', 'sounded', 'calm', 'unperturbed', 'situation', 'said', 'hum', 'nikley', 'shaheed', 'hone', 'main', 'kya', 'karu', 'jisko', 'game', 'khelna', 'hai', 'khelo', 'kabhi', 'hum', 'aage', 'kabhi', 'aap', 'aaj', 'aapne', 'pakad', 'liya', 'mubarak', 'ho', 'aapko', 'jisko', 'jo', 'karna', 'hai', 'karlo', 'left', 'home', 'martyrdom', 'today', 'caught', 'congratulations', 'surrender', 'nahi', 'kar', 'sakta', 'jo', 'meri', 'kismat', 'may', 'likha', 'hoga', 'allah', 'wahi', 'karega', 'theek', 'hai', 'surrender', 'allaah', 'would', 'whatever', 'fate', 'dujana', 'went', 'say', 'dujana', 'belonged', 'pakistan', 'lashkar', 'e', 'taiba', 'divisional', 'commander', 'south', 'kashmir', 'among', 'top', '10', 'terrorists', 'identified', 'indian', 'army', 'jammu', 'kashmir', 'rs', '15', 'lakh', 'bounty', 'head', 'dujana', 'labelled', 'terrorist', 'top', 'grade', 'also', 'given', 'burhan', 'wani', 'security', 'forces', 'received', 'inputs', 'last', 'days', 'frequenting', 'houses', 'wife', 'rukaiya', 'girlfriend', 'shazia', 'police', 'keeping', 'watch', 'houses', 'confirmed', 'present', 'wife', 'house', 'security', 'forces', 'moved', 'trap', 'also', 'read', 'abu', 'dujana', 'security', 'forces', 'prepare', 'new', 'hitlist', 'wanted', 'terroristsabu', 'dujana', 'encounter', 'jilted', 'lover', 'turned', 'police', 'informer', 'led', 'security', 'forces', 'let', 'commander']
#
# Documento 5:
#  - Palabras: ['aarushi', 'maheshwari', 'hotel', 'staff', 'get', 'training', 'spot', 'signs', 'sex', 'trafficking', 'hotels', 'mumbai', 'indian', 'cities', 'train', 'staff', 'spot', 'signs', 'sex', 'trafficking', 'frequent', 'requests', 'bed', 'linen', 'changes', 'disturb', 'sign', 'left', 'door', 'days', 'end', 'group', 'behind', 'initiative', 'also', 'developing', 'mobile', 'phone', 'app', 'rescue', 'hotel', 'staff', 'use', 'alert', 'local', 'police', 'senior', 'anti', 'trafficking', 'officers', 'see', 'suspicious', 'behavior', 'hotels', 'breeding', 'grounds', 'human', 'trade', 'said', 'sanee', 'awsarmmel', 'chairman', 'alumni', 'group', 'maharashtra', 'state', 'institute', 'hotel', 'management', 'catering', 'technology', 'hospitality', 'professionals', 'working', 'hotels', 'across', 'country', 'committed', 'initiative', 'spearheaded', 'alumni', 'group', 'backed', 'maharashtra', 'state', 'government', 'comes', 'amid', 'growing', 'international', 'recognition', 'hotels', 'key', 'role', 'play', 'fighting', 'modern', 'day', 'slavery', 'maharashtra', 'major', 'destination', 'trafficked', 'girls', 'maharashtra', 'mumbai', 'capital', 'major', 'destination', 'trafficked', 'girls', 'lured', 'poor', 'states', 'nearby', 'countries', 'promise', 'jobs', 'sold', 'sex', 'trade', 'domestic', 'servitude', 'rising', 'property', 'prices', 'traditional', 'red', 'light', 'districts', 'like', 'mumbai', 'started', 'disappear', 'pushing', 'sex', 'trade', 'underground', 'private', 'lodges', 'hotels', 'makes', 'hard', 'police', 'monitor', 'awsarmmel', 'said', 'hotels', 'would', 'told', '50', 'signs', 'staff', 'needed', 'watch', 'include', 'requests', 'rooms', 'view', 'car', 'park', 'favored', 'traffickers', 'allow', 'vet', 'clients', 'signs', 'trouble', 'check', 'cars', 'gauge', 'much', 'charge', 'awsarmmel', 'said', 'hotel', 'staff', 'often', 'noticed', 'strange', 'behavior', 'girl', 'reticence', 'check', 'process', 'dependence', 'person', 'accompanying', 'answer', 'questions', 'provide', 'proof', 'identity', 'cases', 'staff', 'ignore', 'signs', 'idea', 'told', 'thomson', 'reuters', 'foundation', 'rescue', 'app', 'rescue', 'app', 'launched', 'couple', 'months', 'text', 'feature', 'hotel', 'staff', 'fill', 'details', 'including', 'room', 'numbers', 'send', 'alert', 'police', 'human', 'trafficking', 'world', 'fastest', 'growing', 'criminal', 'enterprise', 'worth', 'estimated', '150', 'billion', 'year', 'according', 'international', 'labor', 'organization', 'says', 'nearly', '21', 'million', 'people', 'globally', 'victims', 'forced', 'labor', 'trafficking', 'last', 'year', 'major', 'hotel', 'groups', 'including', 'hilton', 'shiva', 'hotels', 'pledged', 'examine', 'supply', 'chains', 'forced', 'labor', 'train', 'staff', 'spot', 'report', 'signs', 'trafficking', 'earlier', 'year', 'mexico', 'city', 'also', 'launched', 'initiative', 'train', 'hotel', 'staff', 'trafficking', 'vijaya', 'rahatkar', 'chairwoman', 'maharashtra', 'state', 'women', 'commission', 'said', 'initiative', 'would', 'impact', 'beyond', 'state', 'alumni', 'group', 'contact', 'million', 'small', 'hotels', 'across', 'india', 'group', 'also', 'developing', 'training', 'module', 'trafficking', 'hotel', 'staff', 'hospitality', 'students', 'could', 'used', 'across', 'country', 'also', 'readfyi', 'legal', 'revenge', 'child', 'sex', 'trafficking', 'survivors', 'get', 'school', 'justice', 'fight', 'battlesmumbai', 'woman', 'dj', 'arrested', 'high', 'profile', 'sex', 'racket', 'case']

# %% [markdown]
# ## 2. Sistema de recuperación de la información que admite consultas especificadas según el modelo booleano
#
# Se lleva a cabo el diseño y la evaluación de un sistema de recuperación de información basado en el modelo booleano, utilizando consultas generales que, en algunos casos, abarcan múltiples documentos del corpus.

# %%
pip install Whoosh
# Out:
# Requirement already satisfied: Whoosh in c:\users\marta\onedrive\escritorio\ia\anaconda\lib\site-packages (2.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from whoosh.index import create_in
from whoosh.fields import Schema, TEXT, ID
from whoosh.qparser import QueryParser
from whoosh.analysis import StemmingAnalyzer
from collections import defaultdict
from tempfile import mkdtemp

# %%
# 2.1. Preparar los datos del corpus

subcorpus = resultados[30:51]

# %%
# 2.2. Definir el esquema de Whoosh

import os
from whoosh.index import create_in
from whoosh.fields import Schema, TEXT, ID
from whoosh.analysis import StemmingAnalyzer

schema = Schema(doc_id=ID(stored=True),
                content=TEXT(stored=True, analyzer=StemmingAnalyzer()))

if not os.path.exists("indice"):
    os.mkdir("indice")

ix = create_in("indice", schema)

# %%
# 2.3. Indexar los documentos
writer = ix.writer()
for i, doc in enumerate(subcorpus):
    joined_content = ' '.join(doc)
    writer.add_document(doc_id=str(i + 30), content=joined_content)
writer.commit()

# %%
# 2.4. Cargar las consultas booleanas
import json

with open("consultas_booleanas_generales.txt", "r", encoding="utf-8") as f:
    consultas = json.load(f)

# %%
from whoosh.qparser import QueryParser
from whoosh.index import open_dir
from whoosh import scoring

# Abrir el índice
ix = open_dir("indice")
parser = QueryParser("content", ix.schema)

# Verificar cuántas consultas se cargaron
print(f"\nNúmero total de consultas cargadas: {len(consultas)}\n")

# Mostrar las primeras 3 para verificar formato
for i, consulta in enumerate(consultas[:3]):
    print(f"Consulta {i+1}:")
    print(f"  Tema: {consulta['tema']}")
    print(f"  Query: {consulta['query']}")
    print(f"  Documentos relevantes: {consulta['documentos']}")
    print("-" * 60)
# Out:
# Número total de consultas cargadas: 296
#
# Consulta 1:
#   Tema: celebridades
#   Query: donald AND trump
#   Documentos relevantes: [32, 33, 35, 37, 40, 43]
# ------------------------------------------------------------
# Consulta 2:
#   Tema: celebridades
#   Query: president
#   Documentos relevantes: [32, 33, 37, 40, 43]
# ------------------------------------------------------------
# Consulta 3:
#   Tema: celebridades
#   Query: dina AND titus
#   Documentos relevantes: [32]
# ------------------------------------------------------------

# %%
# 2.5. Ejecutar las consultas y evaluar

from whoosh.qparser import QueryParser
from whoosh.index import open_dir
from whoosh import scoring

# Abrir el índice
ix = open_dir("indice")
parser = QueryParser("content", ix.schema)

# Inicializar métricas
total_precision = 0
total_recall = 0
num_consultas = len(consultas)

with ix.searcher(weighting=scoring.BM25F()) as searcher:
    for consulta in consultas:
        query_text = consulta["query"]
        documentos_relevantes = set(map(str, consulta["documentos"]))  # convertimos a string
        tema = consulta["tema"]

        # Parsear y ejecutar la consulta
        try:
            query = parser.parse(query_text)
            resultados = searcher.search(query, limit=None)
            documentos_encontrados = set([r['doc_id'] for r in resultados])
        except Exception as e:
            print(f"Error al procesar la consulta '{query_text}': {e}")
            continue

        # Calcular métricas
        verdaderos_positivos = documentos_encontrados & documentos_relevantes
        precision = len(verdaderos_positivos) / len(documentos_encontrados) if documentos_encontrados else 0
        recall = len(verdaderos_positivos) / len(documentos_relevantes) if documentos_relevantes else 0

        # Acumular para métricas promedio
        total_precision += precision
        total_recall += recall

        # Imprimir métricas individuales
        print(f"Tema: {tema}")
        print(f"Consulta: {query_text}")
        print(f"Documentos encontrados: {sorted(documentos_encontrados)}")
        print(f"Documentos relevantes: {sorted(documentos_relevantes)}")
        print(f"Precisión: {precision:.2f}")
        print(f"Recall (Sensibilidad): {recall:.2f}")
        print("-" * 60)
# Out:
# Tema: celebridades
# Consulta: donald AND trump
# Documentos encontrados: ['32', '33', '35', '37', '40', '43']
# Documentos relevantes: ['32', '33', '35', '37', '40', '43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: president
# Documentos encontrados: ['32', '33', '35', '37', '39', '40', '43']
# Documentos relevantes: ['32', '33', '37', '40', '43']
# Precisión: 0.71
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: dina AND titus
# Documentos encontrados: ['32']
# Documentos relevantes: ['32']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: chelsea AND clinton
# Documentos encontrados: ['32']
# Documentos relevantes: ['32']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: anthony AND scaramucci
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: reince AND priebus
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: jon AND huntsman
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: eric AND trump
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: tom AND bossert
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: paul AND ryan
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: sarah AND huckabee AND sanders
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: mike AND pence
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: bannon
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: kushner
# Documentos encontrados: ['33', '35']
# Documentos relevantes: ['35']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: ayesha AND gulalai
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: imran AND khan
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: nawaz AND sharif
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: jk AND rowling
# Documentos encontrados: ['37']
# Documentos relevantes: ['37']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: novelist OR author
# Documentos encontrados: ['30', '36', '37', '47']
# Documentos relevantes: ['37']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: naseem AND khan
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: mohsin AND raza
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: akhilesh AND yadav
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: lindsey AND graham
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: kim AND jong AND un
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: sunil AND pal
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: anees AND bazmee
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: mayur AND barot
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: remo AND dsouza
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: praful AND kodabhai AND patel
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: mohan AND bhagwat
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: rex AND tillerson
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: arun AND jaitley
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: baba AND ramdev
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: sonakshi AND sinha
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: shekhar AND ravjiani
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: kanika AND kapoor
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: aparshakti AND khurana
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: ranveer AND singh
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: mouni AND roy
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: badshah
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: (reality AND show) OR shoot OR performances OR show OR shows
# Documentos encontrados: ['40', '41', '45', '46', '48']
# Documentos relevantes: ['46']
# Precisión: 0.20
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: bollywood
# Documentos encontrados: ['41', '46', '48']
# Documentos relevantes: ['46', '48']
# Precisión: 0.67
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: singer OR rapper
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: actor OR actress OR actors OR director OR star
# Documentos encontrados: ['33', '38', '41', '45', '46', '47', '48']
# Documentos relevantes: ['46', '47', '48']
# Precisión: 0.43
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: songs OR tunes OR music
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: films OR film OR movie OR series
# Documentos encontrados: ['33', '34', '37', '41', '47', '48']
# Documentos relevantes: ['37', '47', '48']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: celebridades
# Consulta: naseeruddin AND shah
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: sunil AND pal
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: anees AND bazmee
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: mayur AND barot
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: remo AND dsouza
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: cintaa
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: great AND indian AND laughter AND challenge
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: nawabzade
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: baba AND ramdev
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: sonakshi AND sinha
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: shekhar AND ravjiani
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: kanika AND kapoor
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: aparshakti AND khurana
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: ranveer AND singh
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: mouni AND roy
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: badshah
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: (life AND ok) OR (star AND bharat)
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: (reality AND show) OR shoot OR performances OR show OR shows OR sets OR set OR function
# Documentos encontrados: ['34', '40', '41', '43', '45', '46', '48']
# Documentos relevantes: ['41', '46', '48']
# Precisión: 0.43
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: media
# Documentos encontrados: ['32', '33', '36', '42', '46']
# Documentos relevantes: ['46']
# Precisión: 0.20
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: produce OR direct
# Documentos encontrados: ['41', '42', '46', '48']
# Documentos relevantes: ['46', '48']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: roadies
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: masterchef OR splisvilla OR naagin
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: bollywood
# Documentos encontrados: ['41', '46', '48']
# Documentos relevantes: ['46', '48']
# Precisión: 0.67
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: singer OR rapper
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: studio
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: actor OR actress OR actors OR director OR star OR filmmakers
# Documentos encontrados: ['33', '38', '41', '45', '46', '47', '48']
# Documentos relevantes: ['46', '47', '48']
# Precisión: 0.43
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: contestants OR host
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: songs OR tunes OR music
# Documentos encontrados: ['46']
# Documentos relevantes: ['46']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: films OR film OR movie OR scene
# Documentos encontrados: ['41', '47', '48']
# Documentos relevantes: ['47', '48']
# Precisión: 0.67
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: lipstick AND burkha
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: cbfc
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: film AND certification AND appellate AND tribunal
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: screen
# Documentos encontrados: ['47', '48']
# Documentos relevantes: ['47', '48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: naseeruddin AND shah
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: ratna AND pathak
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: alankrita AND shrivastava
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: amitabh AND bachchan
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: aamir AND khan
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: katrina AND kaif
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: fatima AND sana AND sheikh
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: rishi AND kapoor
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: vijay AND krishna AND acharya
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: dangal
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: thugs AND hindostan
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: script
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: televisión y cine
# Consulta: adaptation
# Documentos encontrados: ['48']
# Documentos relevantes: ['48']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: rakshabandhan
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: compulsory
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: daman AND diu
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: lady AND staff
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: tie AND rakhis
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: withdrawn
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: hindu AND culture
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: racismo
# Consulta: culture
# Documentos encontrados: ['36', '42']
# Documentos relevantes: ['42']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: arun AND jaitley
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: finance AND minister
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: (competitive AND market) OR (stock AND market) OR shares
# Documentos encontrados: ['41', '44', '45', '48']
# Documentos relevantes: ['44', '45']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: debt
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: divestment
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: loss AND (making OR make)
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: bailout AND package
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: tax
# Documentos encontrados: ['44', '45']
# Documentos relevantes: ['44']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: finance OR financial
# Documentos encontrados: ['33', '44', '45']
# Documentos relevantes: ['44', '45']
# Precisión: 0.67
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: aa
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: bob AND mackenzie
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: misconduct
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: fire OR resignation
# Documentos encontrados: ['33', '37', '45']
# Documentos relevantes: ['45']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: executive AND (chairman OR chief OR director)
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: financial AND performance
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: fix AND cost
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: economía
# Consulta: fraud
# Documentos encontrados: ['45']
# Documentos relevantes: ['45']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: (sexual AND offences) OR (sexual AND assault) OR (sexual AND abuse) OR (assault AND penetration)
# Documentos encontrados: ['34']
# Documentos relevantes: ['34']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: victims
# Documentos encontrados: ['34', '49']
# Documentos relevantes: ['34']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: women AND leaders
# Documentos encontrados: ['36', '39']
# Documentos relevantes: ['36']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: harass OR (obscene AND messages)
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: honour AND women
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: female AND sexuality
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: lady AND oriented
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: biases
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: dictatorial
# Documentos encontrados: ['47']
# Documentos relevantes: ['47']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: feminismo
# Consulta: lady OR women OR female
# Documentos encontrados: ['31', '36', '39', '42', '47']
# Documentos relevantes: ['36', '47']
# Precisión: 0.40
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: police OR cops OR cop OR inspectors OR constable OR constabulary OR asi OR acp OR (head AND constable) OR commissioner OR inspector OR general OR igp OR (security AND forces)
# Documentos encontrados: ['30', '31', '33', '34', '39', '41', '45', '49']
# Documentos relevantes: ['30', '31', '39', '49']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: police AND station
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: departmental AND inquiry
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: pcr
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: harvinder AND singh
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: jurisdiction
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: victim
# Documentos encontrados: ['34', '49']
# Documentos relevantes: ['49']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: passport AND office
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: lathi OR arm OR vigil
# Documentos encontrados: ['39', '40', '50']
# Documentos relevantes: ['39']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: (security AND forces) OR commander OR division OR militant OR militancy OR militants
# Documentos encontrados: ['30', '31', '33', '34']
# Documentos relevantes: ['30', '31']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: operations
# Documentos encontrados: ['30', '31', '39', '50']
# Documentos relevantes: ['30', '31']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: let
# Documentos encontrados: ['30', '31', '41']
# Documentos relevantes: ['30', '31']
# Precisión: 0.67
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: kill OR gunfight OR terrorist OR burial
# Documentos encontrados: ['30', '31']
# Documentos relevantes: ['30', '31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: abu AND dujana
# Documentos encontrados: ['30', '31']
# Documentos relevantes: ['31']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: abu AND ismail
# Documentos encontrados: ['31']
# Documentos relevantes: ['31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: bashir AND lashkari
# Documentos encontrados: ['31']
# Documentos relevantes: ['31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: violence OR criminal OR fir OR ipc OR law OR amendment OR arrest
# Documentos encontrados: ['34', '35', '39', '43']
# Documentos relevantes: ['39']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: fuerzas de seguridad
# Consulta: high AND commission
# Documentos encontrados: ['30']
# Documentos relevantes: ['30']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: police OR cops OR cop OR policeman OR inspector OR head AND constable
# Documentos encontrados: ['30', '34', '39', '41', '49']
# Documentos relevantes: ['30', '39', '49']
# Precisión: 0.60
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: militant OR militants OR militant OR reprisal OR (security AND forces) OR commander
# Documentos encontrados: ['30', '31', '33', '34']
# Documentos relevantes: ['30', '31']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: kill OR slain OR gunfight OR attack OR thrashes OR murder OR attempt
# Documentos encontrados: ['30', '31', '49', '50']
# Documentos relevantes: ['30', '31', '50']
# Precisión: 0.75
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: burial
# Documentos encontrados: ['30']
# Documentos relevantes: ['30']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: abu AND dujana
# Documentos encontrados: ['30', '31']
# Documentos relevantes: ['30', '31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: abu AND ismail
# Documentos encontrados: ['31']
# Documentos relevantes: ['31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: bashir AND lashkari
# Documentos encontrados: ['31']
# Documentos relevantes: ['31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: arif AND lalihaari
# Documentos encontrados: ['30']
# Documentos relevantes: ['30']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: investigations OR investigation OR detectives OR intercepted OR operation
# Documentos encontrados: ['30', '31', '33', '34', '35', '39', '50']
# Documentos relevantes: ['31', '34', '50']
# Precisión: 0.43
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: communication AND intercepts
# Documentos encontrados: ['31']
# Documentos relevantes: ['31']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: email
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: prankster
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: leaks OR (cyber AND issues)
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: justice
# Documentos encontrados: ['33', '41']
# Documentos relevantes: ['33']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: manish AND shah
# Documentos encontrados: ['34']
# Documentos relevantes: ['34']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: sexual AND offences OR sexual AND assault OR sexual AND abuse OR assault AND penetration
# Documentos encontrados: ['34']
# Documentos relevantes: ['34']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: (magistrates AND court) OR court OR litigation OR (supreme AND court)
# Documentos encontrados: ['34', '36', '39', '50']
# Documentos relevantes: ['34', '36', '39', '50']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: crown AND prosecution AND service
# Documentos encontrados: ['34']
# Documentos relevantes: ['34']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: victims
# Documentos encontrados: ['34', '49']
# Documentos relevantes: ['34', '49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: arrested OR arrest OR detention OR imprison
# Documentos encontrados: ['34', '39', '43', '50']
# Documentos relevantes: ['34', '43']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: claims OR charges
# Documentos encontrados: ['30', '33', '34', '36', '39', '41', '43', '47', '49']
# Documentos relevantes: ['34', '39', '43']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: criminal OR contempt OR miscreants OR violate
# Documentos encontrados: ['34', '39']
# Documentos relevantes: ['34', '39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: authority
# Documentos encontrados: ['30', '36', '37', '47']
# Documentos relevantes: ['36']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: imran AND khan
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: ayesha AND gulalai
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: harass OR (obscene AND messages) OR defamatory
# Documentos encontrados: ['36', '41']
# Documentos relevantes: ['36', '41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: facebook
# Documentos encontrados: ['37', '41', '49']
# Documentos relevantes: ['41']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: non AND payment
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: dues OR cheque
# Documentos encontrados: ['34', '41', '45']
# Documentos relevantes: ['41']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: legal AND action
# Documentos encontrados: ['41']
# Documentos relevantes: ['41']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: jk AND rowling
# Documentos encontrados: ['37']
# Documentos relevantes: ['37']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: donald AND trump
# Documentos encontrados: ['32', '33', '35', '37', '40', '43']
# Documentos relevantes: ['37']
# Precisión: 0.17
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: tweets
# Documentos encontrados: ['33', '37']
# Documentos relevantes: ['37']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: apologise
# Documentos encontrados: ['37']
# Documentos relevantes: ['37']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: wrongly AND accuse
# Documentos encontrados: ['37']
# Documentos relevantes: ['37']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: disabled AND child
# Documentos encontrados: ['37']
# Documentos relevantes: ['37']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: sahibabad
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: ghaziabad
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: congress AND workers
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: haj AND house
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: naseem AND khan
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: prohibitory AND orders
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: violence OR damage
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: unidentified
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: court OR litigation
# Documentos encontrados: ['34', '36', '39', '50']
# Documentos relevantes: ['39']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: otto AND warmbier
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: steal
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: death
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: departmental AND inquiry
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: bribe
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: atam AND nagar
# Documentos encontrados: ['49']
# Documentos relevantes: ['49']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: demand
# Documentos encontrados: ['39', '44', '45', '49']
# Documentos relevantes: ['49']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: incident
# Documentos encontrados: ['33', '49']
# Documentos relevantes: ['49']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: convicts OR imprisonment OR guilty
# Documentos encontrados: ['43', '50']
# Documentos relevantes: ['50']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: pirates
# Documentos encontrados: ['50']
# Documentos relevantes: ['50']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: case OR cases
# Documentos encontrados: ['36', '41', '50']
# Documentos relevantes: ['50']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: hostage OR kidnapping OR captured OR rescued
# Documentos encontrados: ['49', '50']
# Documentos relevantes: ['50']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: verdict
# Documentos encontrados: ['50']
# Documentos relevantes: ['50']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: arms OR ammunitions
# Documentos encontrados: ['39', '40', '50']
# Documentos relevantes: ['50']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: crimen e injusticia
# Consulta: coast AND guard
# Documentos encontrados: ['50']
# Documentos relevantes: ['50']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: (donald AND trump) OR president OR prez
# Documentos encontrados: ['32', '33', '35', '37', '39', '40', '43']
# Documentos relevantes: ['32', '33', '35', '40', '43']
# Precisión: 0.71
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: chelsea AND clinton
# Documentos encontrados: ['32']
# Documentos relevantes: ['32']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: dina AND titus
# Documentos encontrados: ['32']
# Documentos relevantes: ['32']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: us OR washington OR (united AND states)
# Documentos encontrados: ['32', '33', '40', '43']
# Documentos relevantes: ['32', '40', '43']
# Precisión: 0.75
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: white AND house
# Documentos encontrados: ['32', '33', '35', '37']
# Documentos relevantes: ['32', '33', '35']
# Precisión: 0.75
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: cnn
# Documentos encontrados: ['32', '33']
# Documentos relevantes: ['32', '33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: democrat OR democratic
# Documentos encontrados: ['32', '35', '43']
# ...
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: paul AND ryan
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: sarah AND huckabee AND sanders
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: mike AND pence
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: bannon
# Documentos encontrados: ['33']
# Documentos relevantes: ['33']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: kushner
# Documentos encontrados: ['33', '35']
# Documentos relevantes: ['35']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: lindsey AND graham
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: kim AND jong AND un
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: north AND korea OR dprk OR pyongyang
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['40', '43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: china
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: united AND nations
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['40']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: senator OR lawmaker
# Documentos encontrados: ['35', '36', '40']
# Documentos relevantes: ['40']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: policy
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: nbc
# Documentos encontrados: ['33', '40']
# Documentos relevantes: ['40']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: diplomacy OR diplomatically OR diplomatic
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: travel AND (ban OR restriction)
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: rex AND tillerson
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: rule AND law
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: ballistic AND missile
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['43']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: federal
# Documentos encontrados: ['43']
# Documentos relevantes: ['43']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de estados unidos
# Consulta: democratic OR republic
# Documentos encontrados: ['32', '35', '43']
# Documentos relevantes: ['43']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: ayesha AND gulalai
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: imran AND khan
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: nawaz AND sharif
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: corruption
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: party
# Documentos encontrados: ['36', '45']
# Documentos relevantes: ['36']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: leaders OR parliamentarian OR spokesman OR lawmaker OR minister OR ministers OR government OR (cabinet AND ministers)
# Documentos encontrados: ['30', '35', '36', '39', '40', '42', '43', '44']
# Documentos relevantes: ['36', '42', '44']
# Precisión: 0.38
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: pti OR (tehreek AND e AND insaf) OR (pml AND n)
# Documentos encontrados: ['36', '37', '44']
# Documentos relevantes: ['36']
# Precisión: 0.33
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: national AND assembly
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: supreme AND court
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: tickets
# Documentos encontrados: ['36']
# Documentos relevantes: ['36']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: mohsin AND raza
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: akhilesh AND yadav
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: praful AND kodabhai AND patel
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: mohan AND bhagwat
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: rss
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: bjp
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: constituencies
# Documentos encontrados: ['42']
# Documentos relevantes: ['42']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: arun AND jaitley
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: tax
# Documentos encontrados: ['44', '45']
# Documentos relevantes: ['44']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: jobs
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: public AND sector
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: demands
# Documentos encontrados: ['39', '44', '45', '49']
# Documentos relevantes: ['44']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: política de india
# Consulta: air AND india
# Documentos encontrados: ['44']
# Documentos relevantes: ['44']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: war
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: north AND korea
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['40']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: (united AND states) OR us
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['40']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: china
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: united AND nations
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['40']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: military
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: destroy
# Documentos encontrados: ['40']
# Documentos relevantes: ['40']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: (ballistic AND missile) OR missile OR icbm OR nuclear OR weapons OR weapon OR arm
# Documentos encontrados: ['39', '40', '43', '50']
# Documentos relevantes: ['40']
# Precisión: 0.25
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: devastate
# Documentos encontrados: []
# Documentos relevantes: ['40']
# Precisión: 0.00
# Recall (Sensibilidad): 0.00
# ------------------------------------------------------------
# Tema: conflictos armados
# Consulta: intercontinental
# Documentos encontrados: ['40', '43']
# Documentos relevantes: ['40']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: vivienda y desarrollo urbano
# Consulta: public AND property
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: vivienda y desarrollo urbano
# Consulta: national AND green AND tribunal
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: vivienda y desarrollo urbano
# Consulta: river AND hindon
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: vivienda y desarrollo urbano
# Consulta: environment
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: pm1 OR pm2 OR pm10 OR (fine AND particles) OR (heavy AND metals)
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: pollutant
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: central AND delhi
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: ministry AND earth AND sciences
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: (vehicular AND combustion) OR construction
# Documentos encontrados: ['38', '39']
# Documentos relevantes: ['38']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: cpcb
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: public AND property
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: national AND green AND tribunal
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: river OR (river AND hindon)
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: medio ambiente
# Consulta: environment OR ecology
# Documentos encontrados: ['39']
# Documentos relevantes: ['39']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: salud
# Consulta: bloodstream OR lungs OR heart OR alveolar
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: salud
# Consulta: dangerous OR harmful OR toxic
# Documentos encontrados: ['38', '43']
# Documentos relevantes: ['38']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: salud
# Consulta: ailments
# Documentos encontrados: ['38']
# Documentos relevantes: ['38']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------

# %%
# 2.6. Métricas promedio

if num_consultas > 0:
    print("\n===== MÉTRICAS PROMEDIO =====")
    print(f"Precisión promedio: {total_precision / num_consultas:.2f}")
    print(f"Recall promedio: {total_recall / num_consultas:.2f}")
# Out:
# ===== MÉTRICAS PROMEDIO =====
# Precisión promedio: 0.86
# Recall promedio: 1.00
