# %% [markdown]
# ## 1. Lectura de datos
#
# Se comenzará con la lectura del corpus, en la cual, entre las técnicas de normalización de términos utilizadas, se encuentra la lematización.

# %%
# !pip install nltk
import nltk

from nltk import download

download('punkt_tab')                           # Tokenización
nltk.download('averaged_perceptron_tagger')     # POS tagging
nltk.download('averaged_perceptron_tagger_eng') # POS tagging
nltk.download('wordnet')                        # WordNet lemmatizer
nltk.download('omw-1.4')                        # WordNet multilingüe
# Out:
# Requirement already satisfied: nltk in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
from nltk.corpus import stopwords
from nltk.data import path
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

path.append(".")

# %%
# !pip install contractions
import contractions
# Out:
# Requirement already satisfied: contractions in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (from textsearch>=0.0.21->contractions) (2.1.0)

# %%
import csv
import pandas as pd
from bs4 import BeautifulSoup
from pprint import pprint
import re
from bs4 import MarkupResemblesLocatorWarning
import warnings

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier

# %%
warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

# %%
palabras_vacias_ingles = stopwords.words('english')

# %%
def elimina_html(contenido):
    return BeautifulSoup(contenido).get_text()

def elimina_no_alfanumerico(contenido):
    return [re.sub(r'[^\w]', '', palabra)
            for palabra in contenido
            if re.search(r'\w', palabra)]

def expandir_constracciones(contenido):
    return contractions.fix(contenido)

def pasar_a_minuscula(contenido):
    return contenido.lower()

def limpiar_texto(texto):
    texto = re.sub(r'[^a-zA-Z0-9\s]', ' ', texto)  # Reemplaza todo lo que no es letra, espacio o número con espacio
    texto = re.sub(r'\s+', ' ', texto).strip()
    return texto

def elimina_palabras_vacias(contenido):
    return [palabra for palabra in contenido if palabra not in palabras_vacias_ingles]

def lematizador(contenido):
    lemmatizer = WordNetLemmatizer()
    pos_tags = pos_tag(contenido)

    resultado = []
    for palabra, tag in pos_tags:
        if tag.startswith('VB'):  # Verbos
            resultado.append(lemmatizer.lemmatize(palabra, pos='v'))  # infinitivo
        else:  # Sustantivos y el resto tal como están
            resultado.append(palabra)

    return resultado

# %%
def proceso_contenido(texto):
    texto = elimina_html(texto)
    texto = expandir_constracciones(texto)
    texto = pasar_a_minuscula(texto)
    texto = limpiar_texto(texto)                # Limpiar antes de tokenizar
    tokens = word_tokenize(texto)               
    tokens = elimina_no_alfanumerico(tokens)    # Limpiar tokens individuales
    tokens = elimina_palabras_vacias(tokens)
    tokens = lematizador(tokens)
    return tokens

# %%
def procesar_csv_corpus(ruta_csv):
    """
    Carga y procesa un archivo CSV con tres columnas: autor, título y cuerpo.
    Aplica la función proceso_contenido a cada parte y devuelve una lista de listas procesadas.
    
    Parámetros:
        ruta_csv (str): Ruta al archivo CSV. Por defecto es "news_corpus.csv".
    
    Retorna:
        list: Lista donde cada elemento es una lista combinada del contenido procesado.
    """
    # Cargar CSV con codificación segura y punto y coma como separador
    df = pd.read_csv(ruta_csv, encoding="latin-1", sep=";", quotechar='"')

    # Verificar que tenga exactamente 3 columnas
    assert df.shape[1] == 3, "El CSV no tiene exactamente 3 columnas. Revisa el separador o las comillas."

    resultados = []

    for _, fila in df.iterrows():
        autor = fila.iloc[0]
        titulo = fila.iloc[1]
        cuerpo = fila.iloc[2]

        autor_proc = proceso_contenido(autor)
        titulo_proc = proceso_contenido(titulo)
        cuerpo_proc = proceso_contenido(cuerpo)

        # Unir las tres listas en una sola lista combinada
        fila_combinada = autor_proc + titulo_proc + cuerpo_proc
        resultados.append(fila_combinada)
    
    return resultados

# %%
def mostrar_documentos_procesados(resultados, n=5):
    """
    Muestra los primeros `n` documentos procesados de una lista de resultados.
    
    Parámetros:
        resultados (list): Lista de listas de palabras procesadas.
        n (int): Número de documentos a mostrar. Por defecto, 5.
    """
    for i, documento in enumerate(resultados[:n]):
        print(f"Documento {i+1}:")
        print(" - Palabras:", documento)
        print()

# %%
# Cargar CSV con codificación segura y punto y coma como separador
ruta_csv="news_corpus.csv"

resultados = procesar_csv_corpus(ruta_csv)
mostrar_documentos_procesados(resultados)
# Out:
# Documento 1:
#  - Palabras: ['chhavi', 'tyagi', 'daman', 'diu', 'revoke', 'mandatory', 'rakshabandhan', 'offices', 'order', 'daman', 'diu', 'administration', 'wednesday', 'withdraw', 'circular', 'ask', 'women', 'staff', 'tie', 'rakhis', 'male', 'colleagues', 'order', 'trigger', 'backlash', 'employees', 'rip', 'apart', 'social', 'media', 'union', 'territory', 'administration', 'force', 'retreat', 'within', '24', 'hours', 'issue', 'circular', 'make', 'compulsory', 'staff', 'celebrate', 'rakshabandhan', 'workplace', 'decide', 'celebrate', 'festival', 'rakshabandhan', 'august', '7', 'connection', 'offices', 'departments', 'shall', 'remain', 'open', 'celebrate', 'festival', 'collectively', 'suitable', 'time', 'wherein', 'lady', 'staff', 'shall', 'tie', 'rakhis', 'colleagues', 'order', 'issue', 'august', '1', 'gurpreet', 'singh', 'deputy', 'secretary', 'personnel', 'say', 'ensure', 'one', 'skipped', 'office', 'attendance', 'report', 'send', 'government', 'next', 'even', 'two', 'notifications', 'one', 'mandate', 'celebration', 'rakshabandhan', 'leave', 'withdraw', 'mandate', 'right', 'issue', 'daman', 'diu', 'administration', 'day', 'apart', 'circular', 'withdrawn', 'one', 'line', 'order', 'issue', 'late', 'evening', 'ut', 'department', 'personnel', 'administrative', 'reforms', 'circular', 'ridiculous', 'sensitivities', 'involve', 'government', 'dictate', 'tie', 'rakhi', 'maintain', 'professionalism', 'workplace', 'official', 'tell', 'hindustan', 'times', 'earlier', 'day', 'refuse', 'identified', 'notice', 'issue', 'daman', 'diu', 'administrator', 'former', 'gujarat', 'home', 'minister', 'praful', 'kodabhai', 'patel', 'direction', 'sources', 'say', 'rakshabandhan', 'celebration', 'bond', 'brothers', 'sisters', 'one', 'several', 'hindu', 'festivities', 'rituals', 'longer', 'confine', 'private', 'family', 'affairs', 'become', 'tools', 'push', 'politic', 'al', 'ideologies', '2014', 'year', 'bjp', 'storm', 'power', 'centre', 'rashtriya', 'swayamsevak', 'sangh', 'rss', 'chief', 'mohan', 'bhagwat', 'say', 'festival', 'national', 'significance', 'celebrate', 'widely', 'protect', 'hindu', 'culture', 'live', 'values', 'enshrine', 'rss', 'ideological', 'parent', 'ruling', 'bjp', 'last', 'year', 'women', 'ministers', 'modi', 'government', 'go', 'border', 'areas', 'celebrate', 'festival', 'soldiers', 'year', 'cabinet', 'ministers', 'ask', 'go', 'constituencies', 'festival']
#
# Documento 2:
#  - Palabras: ['daisy', 'mowke', 'malaika', 'slams', 'user', 'troll', 'divorcing', 'rich', 'man', 'special', 'numbers', 'tv', 'appearances', 'bollywood', 'actor', 'malaika', 'arora', 'khan', 'manage', 'carve', 'identity', 'actor', 'make', 'debut', 'hindi', 'film', 'industry', 'blockbuster', 'debut', 'opposite', 'shah', 'rukh', 'khan', 'chaiyya', 'chaiyya', 'dil', 'se', '1998', 'still', 'remember', 'song', 'however', 'troll', 'woman', 'first', 'matters', 'right', 'divorce', 'rich', 'man', 'wednesday', 'malaika', 'arora', 'share', 'gorgeous', 'picture', 'instagram', 'follower', 'decide', 'troll', 'use', 'alumni', 'read', 'alimony', 'money', 'wear', 'short', 'clothes', 'go', 'gym', 'salon', 'little', 'know', 'munni', 'badnam', 'star', 'would', 'reply', 'perfect', 'comeback', 'take', 'look', 'interaction', 'super', 'excite', 'affiliated', 'khanna', 'jewellers', 'khannajewellerskj', 'brand', 'ambassador', 'craft', 'perfection', 'stun', 'statement', 'jewellery', 'must', 'every', 'jewellery', 'lover', 'khannajewellers', 'maksquad', 'hair', 'hairbypriyanka', 'stylist', 'manekaharisinghani', 'manager', 'ektakauroberoi', 'mua', 'subbu28', 'photographer', 'prasdnaik', 'post', 'share', 'malaika', 'arora', 'khan', 'malaikaarorakhanofficial', 'aug', '2', '2017', '6', '20am', 'pdt', 'malaika', 'decide', 'reply', 'entire', 'conversation', 'prove', 'matter', 'woman', 'successful', 'attack', 'moment', 'decides', 'step', 'bounds', 'society', 'decide', 'apart', 'successful', 'woman', 'live', 'life', 'terms', 'malaika', 'literally', 'play', 'roles', 'traditionally', 'prescribe', 'woman', 'marry', 'quite', 'early', 'son', 'raise', 'always', 'around', 'khandan', 'get', 'divorce', 'alimony', 'taunt', 'thrown', 'details', 'alimony', 'know', 'malaika', 'husband', 'arbaaz', 'khan', 'perhaps', 'family', 'couple', 'handle', 'divorce', 'utmost', 'dignity', 'vouch', 'fact', 'need', 'alimony', 'buy', 'clothes', 'short', 'choice', 'go', 'vacations', 'enjoy', 'life', 'anything', 'successful', 'ex', 'husband', 'happen', 'arbaaz', 'malaika', 'personal', 'concern', 'claim', 'malaika', 'marry', 'divorce', 'arbaaz', 'money', 'hold', 'water', 'agree', 'please', 'get', 'course', 'feminism', 'others', 'playlist', 'popular', 'songs', 'follow', 'htshowbiz']
#
# Documento 3:
#  - Palabras: ['arshiya', 'chopra', 'virgin', 'correct', 'unmarried', 'igims', 'form', 'indira', 'gandhi', 'institute', 'medical', 'sciences', 'igims', 'patna', 'amend', 'marital', 'declaration', 'form', 'thursday', 'replace', 'word', 'virgin', 'unmarried', 'controversy', 'new', 'recruits', 'super', 'specialty', 'medical', 'institute', 'state', 'capital', 'require', 'declare', 'bachelors', 'widowers', 'virgins', 'igims', 'medical', 'superintendent', 'dr', 'manish', 'mandal', 'say', 'institute', 'director', 'dr', 'nr', 'biswas', 'hold', 'meeting', 'thursday', 'morning', 'directing', 'word', 'virgin', 'marital', 'declaration', 'form', 'immediately', 'replace', 'unmarried', 'dr', 'biswas', 'return', 'four', 'day', 'leave', 'absence', 'earlier', 'bihar', 'health', 'minister', 'mangal', 'pandey', 'end', 'redefine', 'mean', 'virginity', 'attempts', 'justify', 'awkward', 'phrase', 'question', 'form', 'follow', 'public', 'furore', 'document', 'wednesday', 'minister', 'tell', 'news', 'channels', 'nothing', 'wrong', 'use', 'word', 'virgin', 'simply', 'meant', 'kanya', 'kunwari', 'mean', 'unmarried', 'girl', 'pandey', 'join', 'cabinet', 'three', 'days', 'ago', 'sources', 'say', 'chief', 'minister', 'office', 'also', 'take', 'cognizance', 'issue', 'ask', 'copy', 'form', 'even', 'ask', 'question', 'introduce', 'first', 'place', 'response', 'management', 'autonomous', 'super', 'specialty', 'health', 'facility', 'clarify', 'wednesday', 'adherence', 'central', 'civil', 'services', 'rules', 'follow', 'india', 'institute', 'medical', 'sciences', 'new', 'delhi', 'previous', 'version', 'marital', 'declaration', 'form', 'purportedly', 'ask', 'new', 'recruits', 'virgins', 'ht', 'photo', 'marital', 'declaration', 'form', 'existence', 'since', 'inception', 'institute', '1983', 'officials', 'blame', 'faux', 'pas', 'poor', 'translation', 'part', 'individuals', 'draft', 'document', 'word', 'virgin', 'mention', 'form', 'nothing', 'virginity', 'employee', 'seek', 'know', 'employees', 'marital', 'status', 'dues', 'could', 'settle', 'basis', 'declaration', 'event', 'death', 'service', 'say', 'dr', 'mandal']
#
# Documento 4:
#  - Palabras: ['sumedha', 'sehra', 'aaj', 'aapne', 'pakad', 'liya', 'let', 'man', 'dujana', 'kill', 'lashkar', 'e', 'taiba', 'kashmir', 'commander', 'abu', 'dujana', 'kill', 'encounter', 'village', 'pulwama', 'district', 'jammu', 'kashmir', 'earlier', 'week', 'dujana', 'manage', 'give', 'security', 'forces', 'slip', 'several', 'times', 'past', 'carry', 'bounty', 'rs', '15', 'lakh', 'head', 'reports', 'say', 'dujana', 'come', 'meet', 'wife', 'trap', 'inside', 'house', 'hakripora', 'village', 'security', 'officials', 'involve', 'encounter', 'try', 'best', 'convince', 'dujana', 'surrender', 'refuse', 'reports', 'say', 'accord', 'reports', 'dujana', 'reject', 'call', 'surrender', 'army', 'officer', 'army', 'commission', 'local', 'start', 'telephonic', 'conversation', 'dujana', 'initiate', 'talk', 'local', 'villager', 'hand', 'phone', 'army', 'officer', 'kya', 'haal', 'hai', 'maine', 'kaha', 'kya', 'haal', 'hai', 'ask', 'dujana', 'heard', 'ask', 'officer', 'officer', 'replies', 'humara', 'haal', 'chhor', 'dujana', 'surrender', 'kyun', 'nahi', 'kar', 'deta', 'tu', 'galat', 'kar', 'rha', 'hai', 'surrender', 'marry', 'girl', 'right', 'tell', 'use', 'pakistani', 'agencies', 'pawn', 'dujana', 'sound', 'calm', 'unperturbed', 'situation', 'say', 'hum', 'nikley', 'shaheed', 'hone', 'main', 'kya', 'karu', 'jisko', 'game', 'khelna', 'hai', 'khelo', 'kabhi', 'hum', 'aage', 'kabhi', 'aap', 'aaj', 'aapne', 'pakad', 'liya', 'mubarak', 'ho', 'aapko', 'jisko', 'jo', 'karna', 'hai', 'karlo', 'leave', 'home', 'martyrdom', 'today', 'catch', 'congratulations', 'surrender', 'nahi', 'kar', 'sakta', 'jo', 'meri', 'kismat', 'may', 'likha', 'hoga', 'allah', 'wahi', 'karega', 'theek', 'hai', 'surrender', 'allaah', 'would', 'whatever', 'fate', 'dujana', 'go', 'say', 'dujana', 'belong', 'pakistan', 'lashkar', 'e', 'taiba', 'divisional', 'commander', 'south', 'kashmir', 'among', 'top', '10', 'terrorists', 'identify', 'indian', 'army', 'jammu', 'kashmir', 'rs', '15', 'lakh', 'bounty', 'head', 'dujana', 'label', 'terrorist', 'top', 'grade', 'also', 'give', 'burhan', 'wani', 'security', 'forces', 'receive', 'inputs', 'last', 'days', 'frequent', 'houses', 'wife', 'rukaiya', 'girlfriend', 'shazia', 'police', 'keep', 'watch', 'houses', 'confirm', 'present', 'wife', 'house', 'security', 'forces', 'move', 'trap', 'also', 'read', 'abu', 'dujana', 'security', 'forces', 'prepare', 'new', 'hitlist', 'want', 'terroristsabu', 'dujana', 'encounter', 'jilt', 'lover', 'turn', 'police', 'informer', 'lead', 'security', 'forces', 'let', 'commander']
#
# Documento 5:
#  - Palabras: ['aarushi', 'maheshwari', 'hotel', 'staff', 'get', 'training', 'spot', 'signs', 'sex', 'trafficking', 'hotels', 'mumbai', 'indian', 'cities', 'train', 'staff', 'spot', 'signs', 'sex', 'traffic', 'frequent', 'requests', 'bed', 'linen', 'changes', 'disturb', 'sign', 'leave', 'door', 'days', 'end', 'group', 'behind', 'initiative', 'also', 'develop', 'mobile', 'phone', 'app', 'rescue', 'hotel', 'staff', 'use', 'alert', 'local', 'police', 'senior', 'anti', 'trafficking', 'officers', 'see', 'suspicious', 'behavior', 'hotels', 'breed', 'grounds', 'human', 'trade', 'say', 'sanee', 'awsarmmel', 'chairman', 'alumni', 'group', 'maharashtra', 'state', 'institute', 'hotel', 'management', 'cater', 'technology', 'hospitality', 'professionals', 'work', 'hotels', 'across', 'country', 'commit', 'initiative', 'spearheaded', 'alumni', 'group', 'back', 'maharashtra', 'state', 'government', 'come', 'amid', 'grow', 'international', 'recognition', 'hotels', 'key', 'role', 'play', 'fight', 'modern', 'day', 'slavery', 'maharashtra', 'major', 'destination', 'traffic', 'girls', 'maharashtra', 'mumbai', 'capital', 'major', 'destination', 'traffic', 'girls', 'lure', 'poor', 'states', 'nearby', 'countries', 'promise', 'jobs', 'sell', 'sex', 'trade', 'domestic', 'servitude', 'rise', 'property', 'prices', 'traditional', 'red', 'light', 'districts', 'like', 'mumbai', 'start', 'disappear', 'push', 'sex', 'trade', 'underground', 'private', 'lodges', 'hotels', 'make', 'hard', 'police', 'monitor', 'awsarmmel', 'say', 'hotels', 'would', 'tell', '50', 'signs', 'staff', 'need', 'watch', 'include', 'requests', 'rooms', 'view', 'car', 'park', 'favor', 'traffickers', 'allow', 'vet', 'clients', 'signs', 'trouble', 'check', 'cars', 'gauge', 'much', 'charge', 'awsarmmel', 'say', 'hotel', 'staff', 'often', 'notice', 'strange', 'behavior', 'girl', 'reticence', 'check', 'process', 'dependence', 'person', 'accompany', 'answer', 'questions', 'provide', 'proof', 'identity', 'cases', 'staff', 'ignore', 'signs', 'idea', 'tell', 'thomson', 'reuters', 'foundation', 'rescue', 'app', 'rescue', 'app', 'launch', 'couple', 'months', 'text', 'feature', 'hotel', 'staff', 'fill', 'details', 'include', 'room', 'numbers', 'send', 'alert', 'police', 'human', 'trafficking', 'world', 'fastest', 'grow', 'criminal', 'enterprise', 'worth', 'estimate', '150', 'billion', 'year', 'accord', 'international', 'labor', 'organization', 'say', 'nearly', '21', 'million', 'people', 'globally', 'victims', 'force', 'labor', 'trafficking', 'last', 'year', 'major', 'hotel', 'groups', 'include', 'hilton', 'shiva', 'hotels', 'pledge', 'examine', 'supply', 'chains', 'force', 'labor', 'train', 'staff', 'spot', 'report', 'signs', 'traffic', 'earlier', 'year', 'mexico', 'city', 'also', 'launch', 'initiative', 'train', 'hotel', 'staff', 'traffic', 'vijaya', 'rahatkar', 'chairwoman', 'maharashtra', 'state', 'women', 'commission', 'say', 'initiative', 'would', 'impact', 'beyond', 'state', 'alumni', 'group', 'contact', 'million', 'small', 'hotels', 'across', 'india', 'group', 'also', 'develop', 'train', 'module', 'traffic', 'hotel', 'staff', 'hospitality', 'students', 'could', 'use', 'across', 'country', 'also', 'readfyi', 'legal', 'revenge', 'child', 'sex', 'traffic', 'survivors', 'get', 'school', 'justice', 'fight', 'battlesmumbai', 'woman', 'dj', 'arrest', 'high', 'profile', 'sex', 'racket', 'case']

# %% [markdown]
# ## 2. Sistema de recuperación de la información que admite consultas especificadas según el modelo booleano
#
# Se diseña y evalúa un sistema de recuperación de información basado en el modelo booleano, empleando consultas específicas formuladas individualmente para cada documento del corpus.

# %%
pip install Whoosh
# Out:
# Requirement already satisfied: Whoosh in c:\users\marta\onedrive\escritorio\ia\anaconda\envs\spacy_env\lib\site-packages (2.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from whoosh.index import create_in
from whoosh.index import open_dir
from whoosh.fields import Schema, TEXT, ID
from whoosh.qparser import QueryParser
from whoosh.analysis import StemmingAnalyzer
from whoosh import scoring
from collections import defaultdict
from tempfile import mkdtemp

# %%
# 2.1. Preparar los datos del corpus

subcorpus = resultados[0:30]

# %%
def crear_indice_whoosh_para_subcorpus(subcorpus, ruta_indice="indice"):
    """
    Crea un índice Whoosh para un subcorpus dado y lo guarda en disco.

    Parámetros:
        subcorpus (list of list of str): Lista de documentos tokenizados.
        ruta_indice (str): Carpeta donde se almacenará el índice Whoosh.
        offset (int): Valor entero que se suma al índice para generar el doc_id.
    """
    schema = Schema(doc_id=ID(stored=True),
                    content=TEXT(stored=True, analyzer=StemmingAnalyzer()))

    if not os.path.exists(ruta_indice):
        os.mkdir(ruta_indice)

    ix = create_in(ruta_indice, schema)
    writer = ix.writer()

    for i, doc in enumerate(subcorpus):
        joined_content = ' '.join(doc)
        writer.add_document(doc_id=str(i), content=joined_content)

    writer.commit()

# %%
# 2.2. Definir el esquema de Whoosh e indexar los documentos

crear_indice_whoosh_para_subcorpus(subcorpus)

# %%
def cargar_consultas_booleanas_especificas(archivo):
    """
    Carga un archivo JSON con consultas booleanas específicas.

    Parámetros:
        archivo (str): Ruta al archivo JSON.

    Retorna:
        list: Lista de consultas cargadas desde el archivo.
    """
    with open(archivo, "r", encoding="utf-8") as f:
        consultas = json.load(f)
    return consultas

def verificar_consultas(consultas):
    """
    Imprime el número total de consultas cargadas y muestra las tres primeras.

    Parámetros:
        consultas (list): Lista de consultas, cada una con los campos 'tema', 'query' y 'documentos'.
    """
    print(f"\nNúmero total de consultas cargadas: {len(consultas)}\n")

    for i, consulta in enumerate(consultas[:3]):
        print(f"Consulta {i+1}:")
        print(f"  Tema: {consulta.get('tema', 'N/A')}")
        print(f"  Query: {consulta.get('query', 'N/A')}")
        print(f"  Documentos relevantes: {consulta.get('documentos', [])}")
        print("-" * 60)

# %%
# 2.3. Cargar las consultas booleanas

archivo="consultas_booleanas_especificas.txt"

consultas = cargar_consultas_booleanas_especificas(archivo)
verificar_consultas(consultas)
# Out:
# Número total de consultas cargadas: 59
#
# Consulta 1:
#   Tema: Imposición de celebraciones religiosas en entornos laborales
#   Query: rakshabandhan AND (office OR offices) AND circular
#   Documentos relevantes: [0]
# ------------------------------------------------------------
# Consulta 2:
#   Tema: Controversias sobre normas laborales y religión
#   Query: government AND festival AND mandatory AND workplace
#   Documentos relevantes: [0]
# ------------------------------------------------------------
# Consulta 3:
#   Tema: Críticas a mujeres famosas tras el divorcio
#   Query: malaika AND divorce AND troll
#   Documentos relevantes: [1]
# ------------------------------------------------------------

# %%
def calcular_metricas(doc_encontrados, doc_relevantes):
    """
    Calcula precisión y recall para una consulta.

    Retorna:
        (precision, recall)
    """
    verdaderos_positivos = doc_encontrados & doc_relevantes
    precision = len(verdaderos_positivos) / len(doc_encontrados) if doc_encontrados else 0
    recall = len(verdaderos_positivos) / len(doc_relevantes) if doc_relevantes else 0
    return precision, recall

def imprimir_metricas_individuales(tema, consulta, encontrados, relevantes, precision, recall):
    """
    Imprime las métricas de una consulta específica.
    """
    print(f"Tema: {tema}")
    print(f"Consulta: {consulta}")
    print(f"Documentos encontrados: {sorted(encontrados)}")
    print(f"Documentos relevantes: {sorted(relevantes)}")
    print(f"Precisión: {precision:.2f}")
    print(f"Recall (Sensibilidad): {recall:.2f}")
    print("-" * 60)

from whoosh.qparser import QueryParser
from whoosh.index import open_dir
from whoosh import scoring

def ejecutar_y_evaluar_consultas(consultas, indice_path):
    """
    Ejecuta todas las consultas usando el índice Whoosh y evalúa precisión y recall.

    Parámetros:
        consultas (list): Lista de consultas con 'query', 'documentos' y 'tema'.
        indice_path (str): Ruta al directorio del índice Whoosh.
    """
    ix = open_dir(indice_path)
    parser = QueryParser("content", ix.schema)

    total_precision = 0
    total_recall = 0
    num_consultas = len(consultas)

    with ix.searcher(weighting=scoring.BM25F()) as searcher:
        for consulta in consultas:
            query_text = consulta["query"]
            documentos_relevantes = set(map(str, consulta["documentos"]))
            tema = consulta["tema"]

            try:
                query = parser.parse(query_text)
                resultados = searcher.search(query, limit=None)
                documentos_encontrados = set([r['doc_id'] for r in resultados])
            except Exception as e:
                print(f"Error al procesar la consulta '{query_text}': {e}")
                continue

            precision, recall = calcular_metricas(documentos_encontrados, documentos_relevantes)
            total_precision += precision
            total_recall += recall

            imprimir_metricas_individuales(tema, query_text, documentos_encontrados, documentos_relevantes, precision, recall)

    return total_precision, total_recall, num_consultas

# %%
# 2.4. Ejecutar las consultas y evaluar

indice_path="indice"
total_precision, total_recall, num_consultas = ejecutar_y_evaluar_consultas(consultas, indice_path)
# Out:
# Tema: Imposición de celebraciones religiosas en entornos laborales
# Consulta: rakshabandhan AND (office OR offices) AND circular
# Documentos encontrados: ['0']
# Documentos relevantes: ['0']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Controversias sobre normas laborales y religión
# Consulta: government AND festival AND mandatory AND workplace
# Documentos encontrados: ['0']
# Documentos relevantes: ['0']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Críticas a mujeres famosas tras el divorcio
# Consulta: malaika AND divorce AND troll
# Documentos encontrados: ['1']
# Documentos relevantes: ['1']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Misoginia en redes sociales hacia mujeres independientes
# Consulta: woman AND successful AND troll AND gym
# Documentos encontrados: ['1']
# Documentos relevantes: ['1']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Controversias por formularios institucionales inapropiados
# Consulta: form AND virgin AND unmarried AND controversy
# Documentos encontrados: ['18', '2']
# Documentos relevantes: ['2']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Lenguaje inapropiado en documentos oficiales
# Consulta: marital AND form AND declaration AND correct
# Documentos encontrados: ['2']
# Documentos relevantes: ['2']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Muerte de terroristas buscados en Cachemira
# Consulta: dujana AND (terrorist OR terrorists) AND encounter AND pulwama
# Documentos encontrados: ['3']
# Documentos relevantes: ['3']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Presión a terroristas para que se rindan
# Consulta: surrender AND army AND dujana
# Documentos encontrados: ['3']
# Documentos relevantes: ['3']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Medidas en hoteles contra la trata de personas
# Consulta: hotel AND trafficking AND training AND staff
# Documentos encontrados: ['4']
# Documentos relevantes: ['4']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Tecnología contra el tráfico sexual en India
# Consulta: rescue AND app AND trafficking AND police
# Documentos encontrados: ['4']
# Documentos relevantes: ['4']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Muerte sospechosa bajo custodia policial
# Consulta: police AND station AND suicide
# Documentos encontrados: ['5']
# Documentos relevantes: ['5']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Sospechas de abuso policial en interrogatorios
# Consulta: death AND interrogation AND torture AND foul
# Documentos encontrados: ['5']
# Documentos relevantes: ['5']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Compensación reducida por negligencia compartida
# Consulta: accident AND compensation AND (negligence OR negligent) AND court
# Documentos encontrados: ['6']
# Documentos relevantes: ['6']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Responsabilidad de peatones en accidentes viales
# Consulta: jaywalker AND accident AND (negligence OR negligent) AND delhi
# Documentos encontrados: ['6']
# Documentos relevantes: ['6']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Linchamiento por histeria colectiva sobre corte de cabello
# Consulta: lynch AND hair AND rumour AND dalit
# Documentos encontrados: ['7']
# Documentos relevantes: ['7']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Casos de histeria colectiva en zonas rurales de India
# Consulta: mass AND hysteria AND (ghost OR ghosts) AND hair AND cut
# Documentos encontrados: ['7']
# Documentos relevantes: ['7']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Accidente de helicóptero por vuelo a baja altitud
# Consulta: helicopter AND crash AND low AND height
# Documentos encontrados: ['8']
# Documentos relevantes: ['8']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Errores humanos en accidentes aéreos en India
# Consulta: (pilot OR pilots) AND disorient AND train AND pawan
# Documentos encontrados: ['8']
# Documentos relevantes: ['8']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Protesta simbólica por inflación del tomate
# Consulta: tomato AND prices AND protest AND congress
# Documentos encontrados: ['9']
# Documentos relevantes: ['9']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Impacto del precio del tomate en India
# Consulta: tomato AND rise AND prices AND lucknow AND bank
# Documentos encontrados: ['9']
# Documentos relevantes: ['9']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Recuperación de alimentos sobrantes para alimentar a necesitados
# Consulta: food AND leftover AND fssai AND hungry
# Documentos encontrados: ['10']
# Documentos relevantes: ['10']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Regulación para bancos de comida en India
# Consulta: fssai AND food AND bank AND regulator
# Documentos encontrados: ['10']
# Documentos relevantes: ['10']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Oferta de trabajo falsa de Google a adolescente
# Consulta: google AND hoax AND job AND boy
# Documentos encontrados: ['11']
# Documentos relevantes: ['11']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Impacto psicológico de ofertas falsas en jóvenes
# Consulta: hoax AND offer AND traumatise AND school
# Documentos encontrados: ['11']
# Documentos relevantes: ['11']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Exención fiscal por ofrecer aparcamiento gratuito en Gurugram
# Consulta: gurugram AND property AND tax AND parking AND waiver
# Documentos encontrados: ['12']
# Documentos relevantes: ['12']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Decisión de edificios comerciales de no ofrecer aparcamiento gratuito
# Consulta: gurugram AND commercial AND buildings AND parking AND tax
# Documentos encontrados: ['12']
# Documentos relevantes: ['12']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Edición genética de embriones humanos para prevenir enfermedades
# Consulta: human AND (embryos OR embryo) AND gene AND crispr AND disease
# Documentos encontrados: ['13']
# Documentos relevantes: ['13']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Riesgos y debate ético sobre la edición genética de embriones
# Consulta: (embryos OR embryo) AND gene AND effects
# Documentos encontrados: ['13']
# Documentos relevantes: ['13']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Edificios peligrosos en Delhi bajo control del gobierno
# Consulta: delhi AND buildings AND unsafe AND cpwd
# Documentos encontrados: ['14']
# Documentos relevantes: ['14']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Revisión anual de edificios inseguros por autoridades municipales
# Consulta: cpwd AND delhi AND survey AND dangerous AND buildings
# Documentos encontrados: ['14']
# Documentos relevantes: ['14']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Elecciones Rajya Sabha con opción NOTA en Gujarat
# Consulta: gujarat AND rajya AND sabha AND nota AND election
# Documentos encontrados: ['15']
# Documentos relevantes: ['15']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Supreme Court mantiene opción NOTA en elecciones de Gujarat
# Consulta: supreme AND court AND gujarat AND election AND nota AND (refuse AND stay)
# Documentos encontrados: ['15']
# Documentos relevantes: ['15']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Atleta indio acusado de abuso sexual en EE.UU.
# Consulta: indian AND athlete AND indict AND sexual AND abuse AND us
# Documentos encontrados: ['16']
# Documentos relevantes: ['16']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Caso legal contra atleta indio en EE.UU. por abuso sexual
# Consulta: tanveer AND hussain AND sexual AND abuse AND indictment AND essex AND county
# Documentos encontrados: ['16']
# Documentos relevantes: ['16']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Falsa alarma de bomba en aeropuerto de Delhi por piezas Maruti
# Consulta: delhi AND airport AND bomb AND scare AND maruti AND spare AND parts
# Documentos encontrados: ['17']
# Documentos relevantes: ['17']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Bomb squad verifica sospecha en aeropuerto de Delhi
# Consulta: cisf, AND bomb AND squad AND delhi AND airport AND cargo AND spare AND parts
# Documentos encontrados: ['17']
# Documentos relevantes: ['17']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Cuestionario controversial sobre virginidad en IGIMS Bihar
# Consulta: igims AND virgin AND questionnaire AND bihar AND marital AND status
# Documentos encontrados: ['18']
# Documentos relevantes: ['18']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Defensa del ministro de salud sobre cuestionario en IGIMS
# Consulta: mangal AND pandey AND igims AND virgin AND marital AND declaration AND controversy
# Documentos encontrados: ['18', '2']
# Documentos relevantes: ['18']
# Precisión: 0.50
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Confusión de grupo antiinmigrante noruego sobre asientos y burkas
# Consulta: norway AND anti AND immigrant AND bus AND seats AND (burqa OR burqas) AND facebook
# Documentos encontrados: ['19']
# Documentos relevantes: ['19']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Reacciones y racismo en grupo noruego tras foto de asientos vacíos
# Consulta: fedrelandet AND viktigst AND norway AND islam AND hatred AND bus AND seats AND (burqa OR burqas)
# Documentos encontrados: ['19']
# Documentos relevantes: ['19']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Bebé nace con gemelo mal formado dentro en Maharashtra
# Consulta: baby AND (fetus OR fetu) AND maharashtra AND malformed AND twin AND rare AND condition
# Documentos encontrados: ['20']
# Documentos relevantes: ['20']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Caso raro de embarazo gemelar monozygotic con fetus in fetu
# Consulta: twin AND pregnancy AND (fetus OR fetu) AND maharashtra AND medical AND anomaly
# Documentos encontrados: ['20']
# Documentos relevantes: ['20']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Prohibición de vendedores ambulantes cerca de AIIMS y Safdarjung en Delhi
# Consulta: aiims AND safdarjung AND hawker AND zone AND delhi AND traffic AND congestion
# Documentos encontrados: ['21']
# Documentos relevantes: ['21']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Medidas para mejorar el tráfico y accesibilidad en hospitales de Delhi
# Consulta: delhi AND ndmc AND hawker AND remove AND ring AND road AND aurobindo AND marg AND hospital AND passage
# Documentos encontrados: ['21']
# Documentos relevantes: ['21']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Protesta de agricultores en Noida por compensación y liberación de arrestados
# Consulta: noida AND farmers AND arrest AND protest AND compensation AND eastern AND peripheral AND expressway
# Documentos encontrados: ['22']
# Documentos relevantes: ['22']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Diálogo entre agricultores y autoridades sobre compensación y protestas en Noida
# Consulta: noida AND farmers AND compensation AND challenge AND arrest AND release AND district AND magistrate
# Documentos encontrados: ['22']
# Documentos relevantes: ['22']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Incidente de casi choque de avión Air Canada en aeropuerto de San Francisco
# Consulta: air AND canada AND san AND francisco AND crash AND taxiway AND ntsb AND (investigation OR investigators)
# Documentos encontrados: ['23']
# Documentos relevantes: ['23']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Confusión de pilotos de Air Canada y sistema de seguridad en aeropuerto SF
# Consulta: air AND canada AND pilots AND mistake AND taxiway AND runway AND aviation AND safety AND (federal AND aviation AND administration)
# Documentos encontrados: ['23']
# Documentos relevantes: ['23']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Aterrizaje de emergencia de avión que mata a dos bañistas en playa de Lisboa
# Consulta: plane AND emergency AND land AND beach AND lisbon AND sunbathers AND kill AND cessna AND aerocondor
# Documentos encontrados: ['24']
# Documentos relevantes: ['24']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Accidente aéreo en playa portuguesa con víctimas fatales
# Consulta: aircraft AND crash AND caparica AND emergency AND land AND (deaths OR dead) AND witnesses
# Documentos encontrados: ['24']
# Documentos relevantes: ['24']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Bloqueo de combustible para vuelos humanitarios de la ONU en Yemen por coalición saudí
# Consulta: yemen AND aid AND flights AND fuel AND (block OR obstruct) AND humanitarian AND crisis
# Documentos encontrados: ['25']
# Documentos relevantes: ['25']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Prueba exitosa de misil balístico intercontinental Minuteman 3 en California
# Consulta: us AND vandenberg AND air AND force AND icbm AND test AND missile AND (launches OR launch)
# Documentos encontrados: ['26']
# Documentos relevantes: ['26']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Contexto geopolítico y pruebas de misiles en EE.UU. ante amenazas de Corea del Norte
# Consulta: us AND missile AND tests AND north AND korea AND tensions AND defense AND system AND bombers AND icbm AND (launches OR launch)
# Documentos encontrados: ['26']
# Documentos relevantes: ['26']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Excursionista alemán hallado congelado en glaciar suizo tras 30 años desaparecido
# Consulta: hiker AND swiss AND alps AND glacier AND (disappear OR disappearance) AND lagginhorn AND mountain
# Documentos encontrados: ['27']
# Documentos relevantes: ['27']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Restos humanos encontrados en glaciar de Suiza décadas después de desaparición
# Consulta: remains AND find AND glacier AND switzerland AND hiker AND (disappear OR disappearance) AND identification
# Documentos encontrados: ['27']
# Documentos relevantes: ['27']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Dilip Kumar hospitalizado en Mumbai por complicaciones renales y deshidratación
# Consulta: dilip AND kumar AND hospitalise AND kidney AND complications AND dehydration AND mumbai AND lilavati AND hospital
# Documentos encontrados: ['28']
# Documentos relevantes: ['28']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Problemas de salud del veterano actor indio Dilip Kumar
# Consulta: bollywood AND actor AND dilip AND kumar AND medical AND complications AND hospital
# Documentos encontrados: ['28']
# Documentos relevantes: ['28']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Manglares de Airoli y Vikhroli en Mumbai entre los más únicos de India
# Consulta: mangrove AND forests AND airoli AND vikhroli AND mumbai AND mangrove AND society AND india AND unique AND locations
# Documentos encontrados: ['29']
# Documentos relevantes: ['29']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------
# Tema: Conservación y turismo en manglares únicos de la India
# Consulta: mangrove AND conservation AND india AND tourism AND potential AND biodiversity AND coastline AND protection
# Documentos encontrados: ['29']
# Documentos relevantes: ['29']
# Precisión: 1.00
# Recall (Sensibilidad): 1.00
# ------------------------------------------------------------

# %%
def mostrar_metricas_promedio(total_precision, total_recall, num_consultas):
    """
    Muestra las métricas promedio de precisión y recall.

    Parámetros:
        total_precision (float): Suma total de precisiones de todas las consultas.
        total_recall (float): Suma total de recalls de todas las consultas.
        num_consultas (int): Número total de consultas evaluadas.
    """
    if num_consultas > 0:
        print("\n===== MÉTRICAS PROMEDIO PARA CONSULTAS ESPECÍFICAS CON LEMATIZACIÓN =====")
        print(f"Precisión promedio: {total_precision / num_consultas:.2f}")
        print(f"Recall promedio: {total_recall / num_consultas:.2f}")
    else:
        print("\nNo se evaluaron consultas, no se pueden calcular métricas promedio.")

# %%
# 2.5. Métricas promedio

mostrar_metricas_promedio(total_precision, total_recall, num_consultas)
# Out:
# ===== MÉTRICAS PROMEDIO PARA CONSULTAS ESPECÍFICAS CON LEMATIZACIÓN =====
# Precisión promedio: 0.98
# Recall promedio: 1.00
